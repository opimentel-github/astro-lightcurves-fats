# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import search_for_filedirs, gather_files_by_kfold
from flamingchoripan.cuteplots.cm_plots import plot_custom_confusion_matrix
import matplotlib.pyplot as plt
from flamingchoripan.datascience.xerror import XError
from IPython.display import display

def get_kf_text(set_name, kf):
    if kf=='.':
        return f'($\\mu\\pm\\sigma$ from 5-fold cross-validation in {set_name}-set)'
    else:
        return f'($\\mu\\pm\\sigma$ from {kf} k-fold in {set_name}-set)'

def get_mode_text(mode, features):
    if mode=='sne':
        return f'Using {len(features)} SNe selected astrophysical features'
    else:
        return f'Using {len(features)} astrophysical features'
    
mode = 'all' # all sne
methods = [
    'linear-fstw',
    'bspline-fstw',
    #'spm-mle-fstw',
    'spm-mcmc-fstw',
    #'spm-mle-estw',
    'spm-mcmc-estw',
]
#methods = ['spm-mcmc-estw']
eval_lcset_name = 'test'
kf = '0'

for method in methods:
    print('='*30+method)
    #for train_config in ['r', 's']:
    for train_config in ['r', 's', 'r+s']:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        features = files[0]()['features']
        cms = np.concatenate([f()['cm'][None] for f in files], axis=0)
        df = files[0]()['wrongs_df']
        display(df)
        #display(df[df['_y']==0])
        #display(df[df['_y']==2])
        assert 0
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ==============================linear-fstw
#               _y  _fullsynth
# ZTF18aacdbzx   3       False
# ZTF18aadmssd   1       False
# ZTF18aaqvuhl   2       False
# ZTF18aarlpzd   3       False
# ZTF18abbvsiv   2       False
# ZTF18abfdupq   2       False
# ZTF18abffyqp   1       False
# ZTF18abilofa   2       False
# ZTF18abkjnqy   3       False
# ZTF18abmoung   2       False
# ZTF18abojpnr   1       False
# ZTF18abvxoty   1       False
# ZTF18abvzdvj   1       False
# ZTF18abwkrbl   1       False
# ZTF18abxbhov   1       False
# ZTF18abzbkby   2       False
# ZTF18acbxsap   2       False
# ZTF18acbzojv   2       False
# ZTF18acnbpkq   2       False
# ZTF18acqppuj   1       False
# ZTF18acrcogn   1       False
# ZTF18acvjnst   2       False
# ZTF18acvwchp   2       False
# ZTF18aczeesl   2       False
# ZTF18adalgmc   2       False
# ZTF19aailqli   2       False
# ZTF19aailvgo   2       False
# ZTF19aalahqa   3       False
# ZTF19aalbrgu   0       False
# ZTF19aalckuo   2       False
# ...           ..         ...
# ZTF20aabcouv   2       False
# ZTF20aabqdbo   2       False
# ZTF20aabqkxs   3       False
# ZTF20aadtarr   1       False
# ZTF20aafmdzj   3       False
# ZTF20aahirfz   1       False
# ZTF20aakodyh   3       False
# ZTF20aanadlu   2       False
# ZTF20aarbget   2       False
# ZTF20aasokxu   2       False
# ZTF20aasxfcd   2       False
# ZTF20aattqcv   2       False
# ZTF20aatulug   2       False
# ZTF20aatuqps   2       False
# ZTF20aatuwib   2       False
# ZTF20aatxryt   2       False
# ZTF20aatznro   2       False
# ZTF20aaurfhs   1       False
# ZTF20aauwjmw   2       False
# ZTF20aavnnat   2       False
# ZTF20aawmcrd   1       False
# ZTF20aaxhzhc   1       False
# ZTF20aayvmyh   1       False
# ZTF20aazhyrs   3       False
# ZTF20aazoqmh   2       False
# ZTF20aazpnxl   2       False
# ZTF20abcgkom   1       False
# ZTF20abchhuw   2       False
# ZTF20abeglzu   2       False
# ZTF20abgbvgl   2       False
#
# [101 rows x 2 columns]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-a04c5000bfd2> in <module>
#      46         #display(df[df['_y']==0])
#      47         #display(df[df['_y']==2])
# ---> 48         assert 0
#
# AssertionError:
