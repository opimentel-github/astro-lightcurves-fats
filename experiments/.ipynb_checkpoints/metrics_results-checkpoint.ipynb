# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import search_for_filedirs, gather_files_by_kfold
from flamingchoripan.cuteplots.cm_plots import plot_custom_confusion_matrix
import matplotlib.pyplot as plt
from flamingchoripan.datascience.xerror import XError
from IPython.display import display

def get_kf_text(set_name, kf):
    if kf=='.':
        return f'($\\mu\\pm\\sigma$ from 5-fold cross-validation in {set_name}-set)'
    else:
        return f'($\\mu\\pm\\sigma$ from {kf} k-fold in {set_name}-set)'

def get_mode_text(mode, features):
    if mode=='sne':
        return f'Using {len(features)} SNe selected astrophysical features'
    else:
        return f'Using {len(features)} astrophysical features'
    
mode = 'all' # all sne
methods = [
    'linear-fstw',
    'bspline-fstw',
    #'spm-mle-fstw',
    'spm-mcmc-fstw',
    #'spm-mle-estw',
    'spm-mcmc-estw',
]
#methods = ['spm-mcmc-estw']
eval_lcset_name = 'test'
kf = '0'

for method in methods:
    print('='*30+method)
    #for train_config in ['r', 's']:
    for train_config in ['r', 's', 'r+s']:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        features = files[0]()['features']
        cms = np.concatenate([f()['cm'][None] for f in files], axis=0)
        bprecision_xe = XError([f()['metrics_dict']['b-precision'] for f in files])
        brecall_xe = XError([f()['metrics_dict']['b-recall'] for f in files])
        bf1score_xe = XError([f()['metrics_dict']['b-f1score'] for f in files])

        ### plot cm
        _title = 'no-method [r]' if train_config=='r' else f'{method} [{train_config}]'
        title = ''
        title += f'features-mode={mode}'+'\n'
        title += f'train-set={_title} - eval-set={kf}@{eval_lcset_name}'+'\n'
        #title += f'b-p/r={bprecision_xe} / {brecall_xe}'+'\n'
        #title += f'b-f1score={bf1score_xe}'+'\n'
        title += f'b-recall={brecall_xe} - b-f1score={bf1score_xe}'+'\n'
        cm_kwargs = {
            'title':title[:-1],
            'figsize':(6,5),
            'new_order_classes':['SNIa', 'SNIbc', 'SNII-b-n', 'SLSN'],
        }
        fig, ax, cm_norm = plot_custom_confusion_matrix(cms, class_names, **cm_kwargs)
        #accu = XError(np.diagonal(cm_norm*100, axis1=1, axis2=2).flatten().tolist())
        #title += f'b-accu={accu}'+'\n'
        #ax.set_title(title[:-1])
        #print(files[0]()['features'])
        caption = ''
        caption += f'Confusion matrix.'
        caption += f' {get_mode_text(mode, features)} {get_kf_text(eval_lcset_name, kf)}'
        print(caption)
        plt.show()
        #assert 0
        print(class_names)
        print(files[0]()['rank'])
        df = files[0]()['wrongs_df']
        #display(df[df['_y']==0])
        #display(df[df['_y']==2])
# Out:
# ==============================linear-fstw
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0446
# [2#] LinearTrend_g=.0379
# [3#] SPM_gamma_r=.0363
# [4#] SPM_t0_r=.0357
# [5#] LinearTrend_r=.0314
# [6#] SPM_gamma_g=.0243
# [7#] SPM_tau_rise_r=.0238
# [8#] SPM_tau_fall_g=.0226
# [9#] Meanvariance_r=.0221
# [10#] SPM_tau_fall_r=.0215
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0550
# [2#] SPM_t0_r=.0403
# [3#] LinearTrend_g=.0370
# [4#] SPM_gamma_r=.0296
# [5#] LinearTrend_r=.0275
# [6#] SPM_tau_rise_r=.0273
# [7#] SPM_gamma_g=.0228
# [8#] SPM_tau_fall_r=.0211
# [9#] Meanvariance_r=.0209
# [10#] SPM_tau_fall_g=.0203
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0506
# [2#] SPM_t0_r=.0403
# [3#] LinearTrend_g=.0383
# [4#] SPM_gamma_r=.0316
# [5#] LinearTrend_r=.0299
# [6#] SPM_tau_rise_r=.0246
# [7#] SPM_gamma_g=.0238
# [8#] Meanvariance_r=.0217
# [9#] SPM_tau_fall_r=.0214
# [10#] SPM_tau_fall_g=.0214
# ==============================bspline-fstw
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0449
# [2#] LinearTrend_g=.0374
# [3#] SPM_t0_r=.0365
# [4#] SPM_gamma_r=.0353
# [5#] LinearTrend_r=.0318
# [6#] SPM_gamma_g=.0243
# [7#] SPM_tau_rise_r=.0241
# [8#] Meanvariance_r=.0230
# [9#] SPM_tau_fall_g=.0220
# [10#] ExcessVar_r=.0212
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0476
# [2#] LinearTrend_g=.0429
# [3#] SPM_t0_r=.0375
# [4#] SPM_gamma_r=.0297
# [5#] LinearTrend_r=.0296
# [6#] SPM_tau_rise_r=.0270
# [7#] SPM_gamma_g=.0254
# [8#] Meanvariance_r=.0209
# [9#] ExcessVar_r=.0195
# [10#] PairSlopeTrend_g=.0168
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0470
# [2#] LinearTrend_g=.0425
# [3#] SPM_t0_r=.0369
# [4#] LinearTrend_r=.0329
# [5#] SPM_gamma_r=.0303
# [6#] SPM_gamma_g=.0263
# [7#] SPM_tau_rise_r=.0250
# [8#] Meanvariance_r=.0220
# [9#] ExcessVar_r=.0214
# [10#] SPM_tau_fall_g=.0189
# ==============================spm-mcmc-fstw
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0445
# [2#] SPM_t0_r=.0364
# [3#] SPM_gamma_r=.0362
# [4#] LinearTrend_g=.0360
# [5#] LinearTrend_r=.0316
# [6#] SPM_tau_rise_r=.0239
# [7#] SPM_gamma_g=.0237
# [8#] Meanvariance_r=.0225
# [9#] SPM_tau_fall_g=.0222
# [10#] SPM_tau_fall_r=.0213
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0551
# [2#] SPM_t0_r=.0422
# [3#] LinearTrend_g=.0389
# [4#] SPM_gamma_r=.0327
# [5#] LinearTrend_r=.0278
# [6#] SPM_tau_rise_r=.0268
# [7#] SPM_gamma_g=.0232
# [8#] PairSlopeTrend_g=.0220
# [9#] SPM_tau_fall_r=.0214
# [10#] Meanvariance_r=.0193
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0507
# [2#] LinearTrend_g=.0413
# [3#] SPM_t0_r=.0386
# [4#] SPM_gamma_r=.0344
# [5#] LinearTrend_r=.0309
# [6#] SPM_tau_rise_r=.0253
# [7#] SPM_gamma_g=.0239
# [8#] Meanvariance_r=.0210
# [9#] SPM_tau_fall_r=.0210
# [10#] SPM_tau_fall_g=.0210
# ==============================spm-mcmc-estw
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0439
# [2#] LinearTrend_g=.0369
# [3#] SPM_t0_r=.0365
# [4#] SPM_gamma_r=.0358
# [5#] LinearTrend_r=.0326
# [6#] SPM_tau_rise_r=.0240
# [7#] Meanvariance_r=.0231
# [8#] SPM_gamma_g=.0230
# [9#] SPM_tau_fall_g=.0222
# [10#] SPM_tau_fall_r=.0214
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0518
# [2#] SPM_t0_r=.0390
# [3#] SPM_gamma_r=.0338
# [4#] LinearTrend_g=.0334
# [5#] SPM_tau_rise_r=.0273
# [6#] LinearTrend_r=.0266
# [7#] SPM_gamma_g=.0247
# [8#] PairSlopeTrend_g=.0226
# [9#] SPM_tau_fall_r=.0216
# [10#] Meanvariance_r=.0201
# Confusion matrix. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0495
# [2#] SPM_t0_r=.0380
# [3#] LinearTrend_g=.0360
# [4#] SPM_gamma_r=.0348
# [5#] LinearTrend_r=.0300
# [6#] SPM_tau_rise_r=.0258
# [7#] SPM_gamma_g=.0246
# [8#] SPM_tau_fall_r=.0211
# [9#] SPM_tau_fall_g=.0205
# [10#] Meanvariance_r=.0205

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

dmetrics = {
    f'b-precision':{'k':1, 'mn':None},
    f'b-recall':{'k':1, 'mn':None},
    f'b-f1score':{'k':1, 'mn':None},
    #f'b-rocauc':{'k':1, 'mn':'b-AUCROC'},
    #f'b-prauc':{'k':1, 'mn':'b-AUCPR'},
    }
info_df = DFBuilder()
for train_config in ['r', 's', 'r+s']:
    aux_r = []
    for method in methods:
        d = {}
        for metric in dmetrics.keys():
            mn = metric if dmetrics[metric]['mn'] is None else dmetrics[metric]['mn']
            rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
            files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
            class_names = files[0]()['lcset_info']['class_names']
            features = files[0]()['features']
            metric_xe = XError([f()['metrics_dict'][metric]*dmetrics[metric]['k'] for f in files])
            d[mn] = metric_xe
            #print(len(metric_xe))
        
        if not train_config=='r': # mean across methods in real case
            info_df.append(f'synthetic-method={method} [{train_config}]', d)
        else:
            aux_r.append(d)

    if train_config=='r': # mean across methods in real case
        print(aux_r)
        new_d = {k:sum([r[k] for r in aux_r]) for k in d.keys()}
        info_df.append(f'synthetic-method=no-method [{train_config}]', new_d)
            
display(info_df())
caption = ''
caption += f'Synthetic generation methods scores using only real samples [r], only synthetic samples [s], and the same proportion of real and synthetic samples [r+s].'
caption += f' {get_mode_text(mode, features)} {get_kf_text(eval_lcset_name, kf)}'

latex_kwargs = {
    'caption':caption,
    'label':'?',
    #'bold_axis':'columns',
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [{'b-precision': .545±.035, 'b-recall': .633±.066, 'b-f1score': .562±.046}, {'b-precision': .545±.035, 'b-recall': .638±.069, 'b-f1score': .566±.047}, {'b-precision': .544±.035, 'b-recall': .638±.067, 'b-f1score': .566±.047}, {'b-precision': .543±.035, 'b-recall': .637±.068, 'b-f1score': .565±.047}]
#                                      b-precision   b-recall  b-f1score
# synthetic-method=no-method [r]         .544±.035  .636±.068  .565±.047
# synthetic-method=linear-fstw [s]       .526±.028  .650±.061  .529±.040
# synthetic-method=bspline-fstw [s]      .506±.023  .596±.049  .490±.026
# synthetic-method=spm-mcmc-fstw [s]     .528±.024  .640±.055  .531±.035
# synthetic-method=spm-mcmc-estw [s]     .528±.022  .633±.047  .530±.032
# synthetic-method=linear-fstw [r+s]     .530±.028  .651±.065  .541±.039
# synthetic-method=bspline-fstw [r+s]    .530±.029  .639±.070  .538±.040
# synthetic-method=spm-mcmc-fstw [r+s]   .531±.023  .645±.055  .541±.034
# synthetic-method=spm-mcmc-estw [r+s]   .535±.025  .646±.054  .544±.035
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{Synthetic generation methods scores using only real samples [r], only synthetic samples [s], and the same proportion of real and synthetic samples [r+s]. Using 102 astrophysical features ($\mu\pm\sigma$ from 5-fold cross-validation in test-set)}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|ccc}
# \hline
# synthetic-method & b-precision & b-recall & b-f1score \srule\\\hline\hline
# no-method [r] & .544$\pm$.035 & .636$\pm$.068 & .565$\pm$.047  \srule\\
# linear-fstw [s] & .526$\pm$.028 & .650$\pm$.061 & .529$\pm$.040  \srule\\
# bspline-fstw [s] & .506$\pm$.023 & .596$\pm$.049 & .490$\pm$.026  \srule\\
# spm-mcmc-fstw [s] & .528$\pm$.024 & .640$\pm$.055 & .531$\pm$.035  \srule\\
# spm-mcmc-estw [s] & .528$\pm$.022 & .633$\pm$.047 & .530$\pm$.032  \srule\\
# linear-fstw [r+s] & .530$\pm$.028 & .651$\pm$.065 & .541$\pm$.039  \srule\\
# bspline-fstw [r+s] & .530$\pm$.029 & .639$\pm$.070 & .538$\pm$.040  \srule\\
# spm-mcmc-fstw [r+s] & .531$\pm$.023 & .645$\pm$.055 & .541$\pm$.034  \srule\\
# spm-mcmc-estw [r+s] & .535$\pm$.025 & .646$\pm$.054 & .544$\pm$.035  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

info_df = DFBuilder()
train_config = 'r+s' # r s r+s
rank_n = 15
for k in range(0, rank_n):
    d = {}
    for method in methods:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        features = files[0]()['features']
        rank = files[0]()['rank'] # just show one
        feature_name, feature_p,_ = rank[k]
        feature_name = feature_name.replace('_', '-')
        d[f'{method} [{train_config}]'] = f'{feature_name} ({feature_p*100:.2f}%)'

    info_df.append(f'k={k+1}', d)

caption = ''
caption += f'Random Forest astrophysical features ranking (top {rank_n}) using the same proportion of real and synthetic samples [r+s].'
caption += f' {get_mode_text(mode, features)}.'

latex_kwargs = {
    'caption':caption,
    'label':'?',
    #'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{Random Forest astrophysical features ranking (top 15) using the same proportion of real and synthetic samples [r+s]. Using 102 astrophysical features.}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|cccc}
# \hline
# k & linear-fstw [r+s] & bspline-fstw [r+s] & spm-mcmc-fstw [r+s] & spm-mcmc-estw [r+s] \srule\\\hline\hline
# 1 & SPM-t0-g (5.07\%) & SPM-t0-g (4.71\%) & SPM-t0-g (5.08\%) & SPM-t0-g (4.95\%)  \srule\\
# 2 & SPM-t0-r (4.03\%) & LinearTrend-g (4.25\%) & LinearTrend-g (4.14\%) & SPM-t0-r (3.81\%)  \srule\\
# 3 & LinearTrend-g (3.84\%) & SPM-t0-r (3.69\%) & SPM-t0-r (3.87\%) & LinearTrend-g (3.60\%)  \srule\\
# 4 & SPM-gamma-r (3.17\%) & LinearTrend-r (3.29\%) & SPM-gamma-r (3.44\%) & SPM-gamma-r (3.49\%)  \srule\\
# 5 & LinearTrend-r (2.99\%) & SPM-gamma-r (3.04\%) & LinearTrend-r (3.10\%) & LinearTrend-r (3.00\%)  \srule\\
# 6 & SPM-tau-rise-r (2.46\%) & SPM-gamma-g (2.64\%) & SPM-tau-rise-r (2.54\%) & SPM-tau-rise-r (2.59\%)  \srule\\
# 7 & SPM-gamma-g (2.39\%) & SPM-tau-rise-r (2.51\%) & SPM-gamma-g (2.40\%) & SPM-gamma-g (2.47\%)  \srule\\
# 8 & Meanvariance-r (2.18\%) & Meanvariance-r (2.21\%) & Meanvariance-r (2.11\%) & SPM-tau-fall-r (2.12\%)  \srule\\
# 9 & SPM-tau-fall-r (2.15\%) & ExcessVar-r (2.14\%) & SPM-tau-fall-r (2.10\%) & SPM-tau-fall-g (2.06\%)  \srule\\
# 10 & SPM-tau-fall-g (2.14\%) & SPM-tau-fall-g (1.90\%) & SPM-tau-fall-g (2.10\%) & Meanvariance-r (2.06\%)  \srule\\
# 11 & ExcessVar-r (2.05\%) & PercentAmplitude-r (1.67\%) & ExcessVar-r (2.04\%) & ExcessVar-r (1.99\%)  \srule\\
# 12 & SPM-beta-r (2.00\%) & PairSlopeTrend-g (1.63\%) & PairSlopeTrend-g (1.83\%) & PairSlopeTrend-g (1.93\%)  \srule\\
# 13 & PairSlopeTrend-g (1.76\%) & MHPS-ratio-g (1.53\%) & SPM-beta-r (1.81\%) & SPM-beta-r (1.69\%)  \srule\\
# 14 & PercentAmplitude-r (1.59\%) & IAR-phi-g (1.49\%) & PercentAmplitude-r (1.67\%) & PercentAmplitude-r (1.66\%)  \srule\\
# 15 & MHPS-ratio-g (1.49\%) & MHPS-high-g (1.48\%) & MHPS-ratio-g (1.46\%) & Skew-r (1.61\%)  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                linear-fstw [r+s]          bspline-fstw [r+s]  \
# k=1             SPM-t0-g (5.07%)            SPM-t0-g (4.71%)
# k=2             SPM-t0-r (4.03%)       LinearTrend-g (4.25%)
# k=3        LinearTrend-g (3.84%)            SPM-t0-r (3.69%)
# k=4          SPM-gamma-r (3.17%)       LinearTrend-r (3.29%)
# k=5        LinearTrend-r (2.99%)         SPM-gamma-r (3.04%)
# k=6       SPM-tau-rise-r (2.46%)         SPM-gamma-g (2.64%)
# k=7          SPM-gamma-g (2.39%)      SPM-tau-rise-r (2.51%)
# k=8       Meanvariance-r (2.18%)      Meanvariance-r (2.21%)
# k=9       SPM-tau-fall-r (2.15%)         ExcessVar-r (2.14%)
# k=10      SPM-tau-fall-g (2.14%)      SPM-tau-fall-g (1.90%)
# k=11         ExcessVar-r (2.05%)  PercentAmplitude-r (1.67%)
# k=12          SPM-beta-r (2.00%)    PairSlopeTrend-g (1.63%)
# k=13    PairSlopeTrend-g (1.76%)        MHPS-ratio-g (1.53%)
# k=14  PercentAmplitude-r (1.59%)           IAR-phi-g (1.49%)
# k=15        MHPS-ratio-g (1.49%)         MHPS-high-g (1.48%)
#
#              spm-mcmc-fstw [r+s]         spm-mcmc-estw [r+s]
# k=1             SPM-t0-g (5.08%)            SPM-t0-g (4.95%)
# k=2        LinearTrend-g (4.14%)            SPM-t0-r (3.81%)
# k=3             SPM-t0-r (3.87%)       LinearTrend-g (3.60%)
# k=4          SPM-gamma-r (3.44%)         SPM-gamma-r (3.49%)
# k=5        LinearTrend-r (3.10%)       LinearTrend-r (3.00%)
# k=6       SPM-tau-rise-r (2.54%)      SPM-tau-rise-r (2.59%)
# k=7          SPM-gamma-g (2.40%)         SPM-gamma-g (2.47%)
# k=8       Meanvariance-r (2.11%)      SPM-tau-fall-r (2.12%)
# k=9       SPM-tau-fall-r (2.10%)      SPM-tau-fall-g (2.06%)
# k=10      SPM-tau-fall-g (2.10%)      Meanvariance-r (2.06%)
# k=11         ExcessVar-r (2.04%)         ExcessVar-r (1.99%)
# k=12    PairSlopeTrend-g (1.83%)    PairSlopeTrend-g (1.93%)
# k=13          SPM-beta-r (1.81%)          SPM-beta-r (1.69%)
# k=14  PercentAmplitude-r (1.67%)  PercentAmplitude-r (1.66%)
# k=15        MHPS-ratio-g (1.46%)              Skew-r (1.61%)
