# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import search_for_filedirs, gather_files_by_kfold
from flamingchoripan.cuteplots.cm_plots import plot_custom_confusion_matrix
import matplotlib.pyplot as plt
from flamingchoripan.datascience.xerror import XError
from IPython.display import display

mode = 'sne' # sne all
methods = [
    'linear-fstw',
    'bspline-fstw',
    'spm-mle-fstw',
    'spm-mcmc-fstw',
    'spm-mle-estw',
    'spm-mcmc-estw',
]
#methods = ['spm-mcmc-estw']
eval_lcset_name = 'test' # val test
kf = '.'

for method in methods:
    print('='*30+method)
    #for train_config in ['r', 's']:
    for train_config in ['r', 's', 'r+s']:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        cms = np.concatenate([f()['cm'][None] for f in files], axis=0)
        bf1score_xe = XError([f()['metrics_dict']['b-f1score'] for f in files])
        bprecision_xe = XError([f()['metrics_dict']['b-precision'] for f in files])
        brecall_xe = XError([f()['metrics_dict']['b-recall'] for f in files])

        ### plot cm
        _title = 'no-method [r]' if train_config=='r' else f'{method} [{train_config}]'
        title = ''
        title += f'train set={_title} - eval={kf}@{eval_lcset_name}'+'\n'
        title += f'b-p/r={bprecision_xe} / {brecall_xe}'+'\n'
        title += f'b-f1score={bf1score_xe}'+'\n'
        cm_kwargs = {
            'title':title[:-1],
            'figsize':(6,5),
            'new_order_classes':['SNIa', 'SNIbc', 'SNII-b-n', 'SLSN'],
        }
        fig, ax, cm_norm = plot_custom_confusion_matrix(cms, class_names, **cm_kwargs)
        #accu = XError(np.diagonal(cm_norm*100, axis1=1, axis2=2).flatten().tolist())
        #title += f'b-accu={accu}'+'\n'
        #ax.set_title(title[:-1])
        #print(files[0]()['features'])
        plt.show()
        #assert 0
        print(class_names)
        print(files[0]()['rank'])
        df = files[0]()['wrongs_df']
        #display(df[df['_y']==0])
        #display(df[df['_y']==2])
# Out:
# ==============================linear-fstw
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0866
# [2#] SPM_gamma_r=.0700
# [3#] SPM_t0_r=.0694
# [4#] LinearTrend_g=.0670
# [5#] LinearTrend_r=.0579
# [6#] SPM_beta_r=.0568
# [7#] SPM_tau_fall_r=.0553
# [8#] SPM_tau_rise_r=.0484
# [9#] SPM_tau_fall_g=.0451
# [10#] SPM_gamma_g=.0432
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1112
# [2#] LinearTrend_g=.0742
# [3#] SPM_t0_r=.0734
# [4#] SPM_tau_rise_r=.0616
# [5#] LinearTrend_r=.0584
# [6#] SPM_gamma_r=.0546
# [7#] SPM_beta_r=.0529
# [8#] SPM_tau_fall_r=.0518
# [9#] SPM_tau_fall_g=.0445
# [10#] SPM_gamma_g=.0381
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1010
# [2#] LinearTrend_g=.0753
# [3#] SPM_t0_r=.0703
# [4#] LinearTrend_r=.0600
# [5#] SPM_gamma_r=.0585
# [6#] SPM_tau_rise_r=.0564
# [7#] SPM_beta_r=.0557
# [8#] SPM_tau_fall_r=.0532
# [9#] SPM_tau_fall_g=.0464
# [10#] SPM_gamma_g=.0399
# ==============================bspline-fstw
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0864
# [2#] SPM_gamma_r=.0699
# [3#] SPM_t0_r=.0674
# [4#] LinearTrend_g=.0667
# [5#] LinearTrend_r=.0591
# [6#] SPM_tau_fall_r=.0554
# [7#] SPM_beta_r=.0554
# [8#] SPM_tau_rise_r=.0480
# [9#] SPM_tau_fall_g=.0452
# [10#] SPM_gamma_g=.0448
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] LinearTrend_g=.0962
# [2#] SPM_t0_g=.0903
# [3#] LinearTrend_r=.0699
# [4#] SPM_t0_r=.0639
# [5#] SPM_tau_rise_r=.0603
# [6#] SPM_gamma_r=.0543
# [7#] SPM_gamma_g=.0474
# [8#] SPM_tau_fall_g=.0385
# [9#] MHPS_low_r=.0358
# [10#] SPM_A_g=.0328
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0907
# [2#] LinearTrend_g=.0899
# [3#] LinearTrend_r=.0703
# [4#] SPM_t0_r=.0647
# [5#] SPM_gamma_r=.0577
# [6#] SPM_tau_rise_r=.0522
# [7#] SPM_gamma_g=.0506
# [8#] SPM_tau_fall_g=.0432
# [9#] SPM_beta_r=.0419
# [10#] MHPS_low_r=.0334
# ==============================spm-mle-fstw
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0820
# [2#] SPM_gamma_r=.0704
# [3#] LinearTrend_g=.0696
# [4#] SPM_t0_r=.0668
# [5#] LinearTrend_r=.0594
# [6#] SPM_beta_r=.0589
# [7#] SPM_tau_fall_r=.0542
# [8#] SPM_tau_rise_r=.0500
# [9#] SPM_gamma_g=.0438
# [10#] SPM_tau_fall_g=.0434
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1085
# [2#] SPM_t0_r=.0773
# [3#] LinearTrend_g=.0750
# [4#] SPM_gamma_r=.0609
# [5#] LinearTrend_r=.0599
# [6#] SPM_tau_rise_r=.0583
# [7#] SPM_beta_r=.0499
# [8#] SPM_tau_fall_r=.0497
# [9#] SPM_tau_fall_g=.0406
# [10#] SPM_gamma_g=.0400
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1015
# [2#] LinearTrend_g=.0742
# [3#] SPM_t0_r=.0684
# [4#] SPM_gamma_r=.0664
# [5#] LinearTrend_r=.0610
# [6#] SPM_tau_rise_r=.0539
# [7#] SPM_beta_r=.0530
# [8#] SPM_tau_fall_r=.0512
# [9#] SPM_tau_fall_g=.0444
# [10#] SPM_gamma_g=.0423
# ==============================spm-mcmc-fstw
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0910
# [2#] SPM_gamma_r=.0700
# [3#] SPM_t0_r=.0664
# [4#] LinearTrend_g=.0643
# [5#] LinearTrend_r=.0595
# [6#] SPM_beta_r=.0580
# [7#] SPM_tau_fall_r=.0552
# [8#] SPM_tau_rise_r=.0473
# [9#] SPM_tau_fall_g=.0451
# [10#] SPM_gamma_g=.0425
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1074
# [2#] LinearTrend_g=.0789
# [3#] SPM_t0_r=.0734
# [4#] SPM_gamma_r=.0635
# [5#] LinearTrend_r=.0601
# [6#] SPM_tau_rise_r=.0591
# [7#] SPM_beta_r=.0510
# [8#] SPM_tau_fall_r=.0509
# [9#] SPM_tau_fall_g=.0410
# [10#] SPM_gamma_g=.0408
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1026
# [2#] LinearTrend_g=.0752
# [3#] SPM_t0_r=.0671
# [4#] SPM_gamma_r=.0631
# [5#] LinearTrend_r=.0619
# [6#] SPM_tau_rise_r=.0592
# [7#] SPM_beta_r=.0533
# [8#] SPM_tau_fall_r=.0521
# [9#] SPM_tau_fall_g=.0443
# [10#] SPM_gamma_g=.0413
# ==============================spm-mle-estw
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0886
# [2#] SPM_gamma_r=.0707
# [3#] LinearTrend_g=.0690
# [4#] SPM_t0_r=.0639
# [5#] LinearTrend_r=.0592
# [6#] SPM_beta_r=.0580
# [7#] SPM_tau_fall_r=.0558
# [8#] SPM_tau_rise_r=.0466
# [9#] SPM_tau_fall_g=.0436
# [10#] SPM_gamma_g=.0430
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1064
# [2#] LinearTrend_g=.0700
# [3#] LinearTrend_r=.0683
# [4#] SPM_gamma_r=.0610
# [5#] SPM_t0_r=.0600
# [6#] SPM_tau_rise_r=.0535
# [7#] SPM_tau_fall_r=.0522
# [8#] SPM_beta_r=.0493
# [9#] SPM_tau_fall_g=.0419
# [10#] SPM_gamma_g=.0375
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0969
# [2#] LinearTrend_g=.0704
# [3#] LinearTrend_r=.0678
# [4#] SPM_gamma_r=.0652
# [5#] SPM_t0_r=.0627
# [6#] SPM_beta_r=.0531
# [7#] SPM_tau_rise_r=.0525
# [8#] SPM_tau_fall_r=.0518
# [9#] SPM_tau_fall_g=.0445
# [10#] SPM_gamma_g=.0408
# ==============================spm-mcmc-estw
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0855
# [2#] LinearTrend_g=.0679
# [3#] SPM_gamma_r=.0678
# [4#] SPM_t0_r=.0656
# [5#] LinearTrend_r=.0605
# [6#] SPM_beta_r=.0569
# [7#] SPM_tau_fall_r=.0558
# [8#] SPM_tau_rise_r=.0485
# [9#] SPM_gamma_g=.0452
# [10#] SPM_tau_fall_g=.0438
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1009
# [2#] LinearTrend_g=.0715
# [3#] SPM_t0_r=.0691
# [4#] SPM_tau_rise_r=.0632
# [5#] SPM_gamma_r=.0627
# [6#] LinearTrend_r=.0580
# [7#] SPM_tau_fall_r=.0504
# [8#] SPM_beta_r=.0491
# [9#] SPM_gamma_g=.0437
# [10#] SPM_tau_fall_g=.0411
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0944
# [2#] LinearTrend_g=.0697
# [3#] SPM_t0_r=.0682
# [4#] SPM_gamma_r=.0642
# [5#] LinearTrend_r=.0610
# [6#] SPM_tau_rise_r=.0589
# [7#] SPM_tau_fall_r=.0533
# [8#] SPM_beta_r=.0509
# [9#] SPM_tau_fall_g=.0458
# [10#] SPM_gamma_g=.0435

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

dmetrics = {
    f'b-precision':{'k':1, 'mn':None},
    f'b-recall':{'k':1, 'mn':None},
    f'b-f1score':{'k':1, 'mn':None},
    #f'b-rocauc':{'k':1, 'mn':'ROCAUC'},
    #f'b-prauc':{'k':1, 'mn':'PRAUC'},
    }
info_df = DFBuilder()
for metric in dmetrics.keys():
    for train_config in ['r', 's', 'r+s']:
    #for train_config in ['r', 's']:
        d = {}
        for method in methods:
            rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
            files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
            metric_xe = XError([f()['metrics_dict'][metric]*dmetrics[metric]['k'] for f in files])
            d[method] = metric_xe
            #print(len(metric_xe))
        
        if train_config=='r': # mean across methods in real case
            new_metric_xe = sum([d[k] for k in d.keys()])
            d = {k:new_metric_xe for k in d.keys()}
            
        mn = dmetrics[metric]['mn']
        info_df.append(f'metric={metric if mn is None else mn} [{train_config}]', d)
        
latex_kwargs = {
    'caption':f'eval-set={kf}@{eval_lcset_name}',
    'label':'?',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
print('% \multicolumn{3}{c|}{}')
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{eval-set=.@test}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|cccc|cc}
# \hline
# metric & linear-fstw & bspline-fstw & spm-mle-fstw & spm-mcmc-fstw & spm-mle-estw & spm-mcmc-estw \srule\\\hline\hline
# b-precision [r] & .593$\pm$.047 & .593$\pm$.047 & .593$\pm$.047 & .593$\pm$.047 & .593$\pm$.047 & .593$\pm$.047  \srule\\
# b-precision [s] & .549$\pm$.025 & .526$\pm$.031 & .549$\pm$.026 & .547$\pm$.027 & .549$\pm$.025 & .552$\pm$.023  \srule\\
# b-precision [r+s] & .570$\pm$.032 & .564$\pm$.025 & .571$\pm$.026 & .578$\pm$.032 & .572$\pm$.026 & .577$\pm$.021  \srule\\
# \hline
# b-recall [r] & .565$\pm$.054 & .565$\pm$.054 & .565$\pm$.054 & .565$\pm$.054 & .565$\pm$.054 & .565$\pm$.054  \srule\\
# b-recall [s] & .642$\pm$.039 & .605$\pm$.040 & .650$\pm$.049 & .642$\pm$.042 & .650$\pm$.045 & .650$\pm$.041  \srule\\
# b-recall [r+s] & .658$\pm$.054 & .632$\pm$.041 & .660$\pm$.044 & .663$\pm$.051 & .656$\pm$.042 & .661$\pm$.043  \srule\\
# \hline
# b-f1score [r] & .570$\pm$.047 & .570$\pm$.047 & .570$\pm$.047 & .570$\pm$.047 & .570$\pm$.047 & .570$\pm$.047  \srule\\
# b-f1score [s] & .558$\pm$.037 & .533$\pm$.042 & .558$\pm$.037 & .559$\pm$.038 & .558$\pm$.037 & .566$\pm$.034  \srule\\
# b-f1score [r+s] & .585$\pm$.043 & .577$\pm$.032 & .589$\pm$.034 & .597$\pm$.040 & .589$\pm$.032 & .596$\pm$.029  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# % \multicolumn{3}{c|}{}
#                          linear-fstw bspline-fstw spm-mle-fstw spm-mcmc-fstw  \
# metric=b-precision [r]     .593±.047    .593±.047    .593±.047     .593±.047
# metric=b-precision [s]     .549±.025    .526±.031    .549±.026     .547±.027
# metric=b-precision [r+s]   .570±.032    .564±.025    .571±.026     .578±.032
# metric=b-recall [r]        .565±.054    .565±.054    .565±.054     .565±.054
# metric=b-recall [s]        .642±.039    .605±.040    .650±.049     .642±.042
# metric=b-recall [r+s]      .658±.054    .632±.041    .660±.044     .663±.051
# metric=b-f1score [r]       .570±.047    .570±.047    .570±.047     .570±.047
# metric=b-f1score [s]       .558±.037    .533±.042    .558±.037     .559±.038
# metric=b-f1score [r+s]     .585±.043    .577±.032    .589±.034     .597±.040
#
#                          spm-mle-estw spm-mcmc-estw
# metric=b-precision [r]      .593±.047     .593±.047
# metric=b-precision [s]      .549±.025     .552±.023
# metric=b-precision [r+s]    .572±.026     .577±.021
# metric=b-recall [r]         .565±.054     .565±.054
# metric=b-recall [s]         .650±.045     .650±.041
# metric=b-recall [r+s]       .656±.042     .661±.043
# metric=b-f1score [r]        .570±.047     .570±.047
# metric=b-f1score [s]        .558±.037     .566±.034
# metric=b-f1score [r+s]      .589±.032     .596±.029

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

info_df = DFBuilder()
train_config = 'r+s' # r s r+s
rank_n = 10
for k in range(0, rank_n):
    d = {}
    for method in methods:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        rank = files[0]()['rank']
        #print(rank)
        feature_name, feature_p,_ = rank[k]
        feature_name = feature_name.replace('_', '-')
        d[f'{method} [{train_config}]'] = f'{feature_name} ({feature_p*100:.3f}%)'

    info_df.append(f'rank={k+1}', d)

latex_kwargs = {
    'caption':f'eval-set={kf}@{eval_lcset_name}',
    'label':'?',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    #'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{eval-set=.@test}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|cccc|cc}
# \hline
# rank & linear-fstw [r+s] & bspline-fstw [r+s] & spm-mle-fstw [r+s] & spm-mcmc-fstw [r+s] & spm-mle-estw [r+s] & spm-mcmc-estw [r+s] \srule\\\hline\hline
# 1 & SPM-t0-g (10.105\%) & SPM-t0-g (9.077\%) & SPM-t0-g (10.156\%) & SPM-t0-g (10.265\%) & SPM-t0-g (9.691\%) & SPM-t0-g (9.443\%)  \srule\\
# 2 & LinearTrend-g (7.535\%) & LinearTrend-g (8.992\%) & LinearTrend-g (7.427\%) & LinearTrend-g (7.529\%) & LinearTrend-g (7.047\%) & LinearTrend-g (6.977\%)  \srule\\
# 3 & SPM-t0-r (7.030\%) & LinearTrend-r (7.039\%) & SPM-t0-r (6.847\%) & SPM-t0-r (6.718\%) & LinearTrend-r (6.783\%) & SPM-t0-r (6.827\%)  \srule\\
# 4 & LinearTrend-r (6.007\%) & SPM-t0-r (6.478\%) & SPM-gamma-r (6.647\%) & SPM-gamma-r (6.317\%) & SPM-gamma-r (6.525\%) & SPM-gamma-r (6.429\%)  \srule\\
# 5 & SPM-gamma-r (5.856\%) & SPM-gamma-r (5.774\%) & LinearTrend-r (6.103\%) & LinearTrend-r (6.197\%) & SPM-t0-r (6.275\%) & LinearTrend-r (6.104\%)  \srule\\
# 6 & SPM-tau-rise-r (5.643\%) & SPM-tau-rise-r (5.221\%) & SPM-tau-rise-r (5.393\%) & SPM-tau-rise-r (5.927\%) & SPM-beta-r (5.314\%) & SPM-tau-rise-r (5.897\%)  \srule\\
# 7 & SPM-beta-r (5.573\%) & SPM-gamma-g (5.061\%) & SPM-beta-r (5.309\%) & SPM-beta-r (5.333\%) & SPM-tau-rise-r (5.252\%) & SPM-tau-fall-r (5.331\%)  \srule\\
# 8 & SPM-tau-fall-r (5.324\%) & SPM-tau-fall-g (4.321\%) & SPM-tau-fall-r (5.121\%) & SPM-tau-fall-r (5.216\%) & SPM-tau-fall-r (5.182\%) & SPM-beta-r (5.095\%)  \srule\\
# 9 & SPM-tau-fall-g (4.642\%) & SPM-beta-r (4.195\%) & SPM-tau-fall-g (4.443\%) & SPM-tau-fall-g (4.438\%) & SPM-tau-fall-g (4.455\%) & SPM-tau-fall-g (4.583\%)  \srule\\
# 10 & SPM-gamma-g (3.997\%) & MHPS-low-r (3.346\%) & SPM-gamma-g (4.232\%) & SPM-gamma-g (4.134\%) & SPM-gamma-g (4.084\%) & SPM-gamma-g (4.351\%)  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                linear-fstw [r+s]       bspline-fstw [r+s]  \
# rank=1        SPM-t0-g (10.105%)        SPM-t0-g (9.077%)
# rank=2    LinearTrend-g (7.535%)   LinearTrend-g (8.992%)
# rank=3         SPM-t0-r (7.030%)   LinearTrend-r (7.039%)
# rank=4    LinearTrend-r (6.007%)        SPM-t0-r (6.478%)
# rank=5      SPM-gamma-r (5.856%)     SPM-gamma-r (5.774%)
# rank=6   SPM-tau-rise-r (5.643%)  SPM-tau-rise-r (5.221%)
# rank=7       SPM-beta-r (5.573%)     SPM-gamma-g (5.061%)
# rank=8   SPM-tau-fall-r (5.324%)  SPM-tau-fall-g (4.321%)
# rank=9   SPM-tau-fall-g (4.642%)      SPM-beta-r (4.195%)
# rank=10     SPM-gamma-g (3.997%)      MHPS-low-r (3.346%)
#
#               spm-mle-fstw [r+s]      spm-mcmc-fstw [r+s]  \
# rank=1        SPM-t0-g (10.156%)       SPM-t0-g (10.265%)
# rank=2    LinearTrend-g (7.427%)   LinearTrend-g (7.529%)
# rank=3         SPM-t0-r (6.847%)        SPM-t0-r (6.718%)
# rank=4      SPM-gamma-r (6.647%)     SPM-gamma-r (6.317%)
# rank=5    LinearTrend-r (6.103%)   LinearTrend-r (6.197%)
# rank=6   SPM-tau-rise-r (5.393%)  SPM-tau-rise-r (5.927%)
# rank=7       SPM-beta-r (5.309%)      SPM-beta-r (5.333%)
# rank=8   SPM-tau-fall-r (5.121%)  SPM-tau-fall-r (5.216%)
# rank=9   SPM-tau-fall-g (4.443%)  SPM-tau-fall-g (4.438%)
# rank=10     SPM-gamma-g (4.232%)     SPM-gamma-g (4.134%)
#
#               spm-mle-estw [r+s]      spm-mcmc-estw [r+s]
# rank=1         SPM-t0-g (9.691%)        SPM-t0-g (9.443%)
# rank=2    LinearTrend-g (7.047%)   LinearTrend-g (6.977%)
# rank=3    LinearTrend-r (6.783%)        SPM-t0-r (6.827%)
# rank=4      SPM-gamma-r (6.525%)     SPM-gamma-r (6.429%)
# rank=5         SPM-t0-r (6.275%)   LinearTrend-r (6.104%)
# rank=6       SPM-beta-r (5.314%)  SPM-tau-rise-r (5.897%)
# rank=7   SPM-tau-rise-r (5.252%)  SPM-tau-fall-r (5.331%)
# rank=8   SPM-tau-fall-r (5.182%)      SPM-beta-r (5.095%)
# rank=9   SPM-tau-fall-g (4.455%)  SPM-tau-fall-g (4.583%)
# rank=10     SPM-gamma-g (4.084%)     SPM-gamma-g (4.351%)
