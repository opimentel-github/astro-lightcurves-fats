# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import search_for_filedirs, gather_files_by_kfold
from flamingchoripan.cuteplots.cm_plots import plot_custom_confusion_matrix
import matplotlib.pyplot as plt
from flamingchoripan.datascience.xerror import XError

methods = [
    'bspline-fstw',
    'linear-fstw',
    #'spm-mle-fstw',
    'spm-mcmc-fstw',
    #'spm-mle-estw',
    'spm-mcmc-estw',
]
#methods = ['spm-mcmc-estw']
eval_lcset_name = 'test' # val test
kf = '0'

for train_config in ['r', 's', 'r+s']:
    for method in methods:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        cms = np.concatenate([f()['cm'][None] for f in files], axis=0)
        f1score_xe = XError([f()['metrics_dict']['b-f1score'] for f in files])
        accuracy_xe = XError([f()['metrics_dict']['b-accuracy'] for f in files])
        print(cms.shape)

        ### plot cm
        _title = 'no-method [r]' if train_config=='r' else f'{method} [{train_config}]'
        title = ''
        title += f'train set={_title} - eval={kf}@{eval_lcset_name}'+'\n'
        title += f'b-f1score={f1score_xe}'+'\n'
        title += f'b-accuracy={accuracy_xe}%'+'\n'
        cm_kwargs = {
            'title':title[:-1],
            'figsize':(6,5),
            'new_order_classes':['SNIa', 'SNIbc', 'allSNII', 'SLSN'],
        }
        fig, ax = plot_custom_confusion_matrix(cms, class_names, **cm_kwargs)
        plt.show()
# Out:
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)
# (150, 4, 4)

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

metrics = [
    'b-accuracy',
    'b-f1score',
    'b-gmean',
    #'b-dpower',
    'b-xentropy',
]
info_df = DFBuilder()
for metric in metrics:
    for train_config in ['r', 's', 'r+s']:
        d = {}
        for method in methods:
            rootdir = f'../save/exp=rf_eval~train_config={train_config}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
            files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
            metric_xe = XError([f()['metrics_dict'][metric] for f in files])
            d[method] = metric_xe

        info_df.append(f'metric={metric} [{train_config}]', d)
        
latex_kwargs = {
    'caption':f'eval={kf}@{eval_lcset_name}',
    'label':'?',
    #'bold_criteriums':'max',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
print('% \multicolumn{3}{c|}{}')
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{eval=.@test}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|ccc|c}
# \hline
# metric & bspline-fstw & linear-fstw & spm-mcmc-fstw & spm-mcmc-estw \srule\\\hline\hline
# b-accuracy [r] & 61.769$\pm$4.628 & 61.537$\pm$4.589 & 61.685$\pm$4.722 & 61.642$\pm$4.660  \srule\\
# b-accuracy [s] & 59.188$\pm$6.704 & 67.338$\pm$8.442 & 65.077$\pm$7.342 & 66.039$\pm$8.116  \srule\\
# b-accuracy [r+s] & 65.641$\pm$6.241 & 67.234$\pm$5.022 & 66.145$\pm$4.493 & 66.288$\pm$4.918  \srule\\
# \hline
# b-f1score [r] & .471$\pm$.032 & .469$\pm$.031 & .470$\pm$.031 & .470$\pm$.031  \srule\\
# b-f1score [s] & .507$\pm$.067 & .567$\pm$.058 & .532$\pm$.064 & .531$\pm$.071  \srule\\
# b-f1score [r+s] & .588$\pm$.070 & .591$\pm$.048 & .575$\pm$.051 & .559$\pm$.042  \srule\\
# \hline
# b-gmean [r] & .733$\pm$.025 & .731$\pm$.025 & .732$\pm$.026 & .732$\pm$.025  \srule\\
# b-gmean [s] & .703$\pm$.036 & .774$\pm$.056 & .758$\pm$.047 & .760$\pm$.054  \srule\\
# b-gmean [r+s] & .760$\pm$.038 & .777$\pm$.035 & .771$\pm$.031 & .770$\pm$.035  \srule\\
# \hline
# b-xentropy [r] & 1.044$\pm$.108 & 1.044$\pm$.107 & 1.044$\pm$.108 & 1.045$\pm$.108  \srule\\
# b-xentropy [s] & 1.138$\pm$.259 & 1.041$\pm$.263 & 1.007$\pm$.245 & 1.026$\pm$.219  \srule\\
# b-xentropy [r+s] & 1.047$\pm$.223 & 1.056$\pm$.253 & 1.027$\pm$.244 & 1.034$\pm$.228  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# % \multicolumn{3}{c|}{}
#                          bspline-fstw   linear-fstw spm-mcmc-fstw  \
# metric=b-accuracy [r]    61.769±4.628  61.537±4.589  61.685±4.722
# metric=b-accuracy [s]    59.188±6.704  67.338±8.442  65.077±7.342
# metric=b-accuracy [r+s]  65.641±6.241  67.234±5.022  66.145±4.493
# metric=b-f1score [r]        .471±.032     .469±.031     .470±.031
# metric=b-f1score [s]        .507±.067     .567±.058     .532±.064
# metric=b-f1score [r+s]      .588±.070     .591±.048     .575±.051
# metric=b-gmean [r]          .733±.025     .731±.025     .732±.026
# metric=b-gmean [s]          .703±.036     .774±.056     .758±.047
# metric=b-gmean [r+s]        .760±.038     .777±.035     .771±.031
# metric=b-xentropy [r]      1.044±.108    1.044±.107    1.044±.108
# metric=b-xentropy [s]      1.138±.259    1.041±.263    1.007±.245
# metric=b-xentropy [r+s]    1.047±.223    1.056±.253    1.027±.244
#
#                         spm-mcmc-estw
# metric=b-accuracy [r]    61.642±4.660
# metric=b-accuracy [s]    66.039±8.116
# metric=b-accuracy [r+s]  66.288±4.918
# metric=b-f1score [r]        .470±.031
# metric=b-f1score [s]        .531±.071
# metric=b-f1score [r+s]      .559±.042
# metric=b-gmean [r]          .732±.025
# metric=b-gmean [s]          .760±.054
# metric=b-gmean [r+s]        .770±.035
# metric=b-xentropy [r]      1.045±.108
# metric=b-xentropy [s]      1.026±.219
# metric=b-xentropy [r+s]    1.034±.228

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

info_df = DFBuilder()
train_config = 'r+s'
rank_n = 15
for k in range(0, rank_n):
    d = {}
    for method in methods:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        rank = files[0]()['rank']
        #print(rank)
        feature_name, feature_p,_ = rank[k]
        feature_name = feature_name.replace('_', '-')
        d[f'{method} [{train_config}]'] = f'{feature_name} ({feature_p*100:.3f}%)'

    info_df.append(f'feature-rank={k+1}', d)

latex_kwargs = {
    'caption':f'eval={kf}@{eval_lcset_name}',
    'label':'?',
    #'bold_criteriums':'max',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{eval=.@test}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|ccc|c}
# \hline
# feature-rank & bspline-fstw [r+s] & linear-fstw [r+s] & spm-mcmc-fstw [r+s] & spm-mcmc-estw [r+s] \srule\\\hline\hline
# 1 & SPM-t0-g (19.946\%) & SPM-t0-g (16.499\%) & SPM-gamma-r (17.376\%) & SPM-gamma-r (20.421\%)  \srule\\
# 2 & SPM-gamma-r (14.243\%) & SPM-gamma-r (13.990\%) & SPM-t0-g (16.357\%) & SPM-t0-r (9.826\%)  \srule\\
# 3 & SPM-gamma-g (5.896\%) & SPM-t0-r (7.482\%) & SPM-t0-r (8.111\%) & SPM-t0-g (7.745\%)  \srule\\
# \hline
# 4 & SPM-t0-r (5.495\%) & SPM-tau-fall-r (7.298\%) & SPM-tau-fall-r (7.524\%) & SPM-beta-r (7.466\%)  \srule\\
# 5 & SPM-tau-rise-r (5.407\%) & SPM-gamma-g (6.802\%) & SPM-beta-r (6.454\%) & SPM-tau-fall-r (7.108\%)  \srule\\
# 6 & SPM-beta-r (4.943\%) & SPM-beta-r (6.122\%) & SPM-tau-fall-g (5.135\%) & SPM-gamma-g (5.972\%)  \srule\\
# \hline
# 7 & SPM-tau-fall-g (4.899\%) & SPM-tau-fall-g (5.597\%) & SPM-tau-rise-r (5.118\%) & SPM-tau-rise-r (5.860\%)  \srule\\
# 8 & LinearTrend-g (4.693\%) & SPM-beta-g (5.228\%) & SPM-beta-g (5.101\%) & SPM-tau-fall-g (4.474\%)  \srule\\
# 9 & SPM-tau-fall-r (4.569\%) & SPM-tau-rise-r (5.185\%) & SPM-gamma-g (4.761\%) & LinearTrend-g (4.314\%)  \srule\\
# \hline
# 10 & LinearTrend-r (4.510\%) & LinearTrend-g (4.337\%) & LinearTrend-g (4.009\%) & SPM-beta-g (3.924\%)  \srule\\
# 11 & SPM-beta-g (4.052\%) & LinearTrend-r (3.296\%) & LinearTrend-r (3.037\%) & SPM-tau-rise-g (3.838\%)  \srule\\
# 12 & IAR-phi-r (3.771\%) & IAR-phi-r (3.202\%) & IAR-phi-r (2.804\%) & IAR-phi-r (3.435\%)  \srule\\
# \hline
# 13 & IAR-phi-g (3.645\%) & IAR-phi-g (3.182\%) & SPM-tau-rise-g (2.797\%) & LinearTrend-r (3.168\%)  \srule\\
# 14 & SPM-tau-rise-g (3.564\%) & SPM-tau-rise-g (3.090\%) & IAR-phi-g (2.681\%) & IAR-phi-g (3.165\%)  \srule\\
# 15 & MHPS-low-g (3.136\%) & MHPS-low-g (2.362\%) & MHPS-low-g (2.528\%) & MHPS-low-r (2.693\%)  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       bspline-fstw [r+s]        linear-fstw [r+s]  \
# feature-rank=1        SPM-t0-g (19.946%)       SPM-t0-g (16.499%)
# feature-rank=2     SPM-gamma-r (14.243%)    SPM-gamma-r (13.990%)
# feature-rank=3      SPM-gamma-g (5.896%)        SPM-t0-r (7.482%)
# feature-rank=4         SPM-t0-r (5.495%)  SPM-tau-fall-r (7.298%)
# feature-rank=5   SPM-tau-rise-r (5.407%)     SPM-gamma-g (6.802%)
# feature-rank=6       SPM-beta-r (4.943%)      SPM-beta-r (6.122%)
# feature-rank=7   SPM-tau-fall-g (4.899%)  SPM-tau-fall-g (5.597%)
# feature-rank=8    LinearTrend-g (4.693%)      SPM-beta-g (5.228%)
# feature-rank=9   SPM-tau-fall-r (4.569%)  SPM-tau-rise-r (5.185%)
# feature-rank=10   LinearTrend-r (4.510%)   LinearTrend-g (4.337%)
# feature-rank=11      SPM-beta-g (4.052%)   LinearTrend-r (3.296%)
# feature-rank=12       IAR-phi-r (3.771%)       IAR-phi-r (3.202%)
# feature-rank=13       IAR-phi-g (3.645%)       IAR-phi-g (3.182%)
# feature-rank=14  SPM-tau-rise-g (3.564%)  SPM-tau-rise-g (3.090%)
# feature-rank=15      MHPS-low-g (3.136%)      MHPS-low-g (2.362%)
#
#                      spm-mcmc-fstw [r+s]      spm-mcmc-estw [r+s]
# feature-rank=1     SPM-gamma-r (17.376%)    SPM-gamma-r (20.421%)
# feature-rank=2        SPM-t0-g (16.357%)        SPM-t0-r (9.826%)
# feature-rank=3         SPM-t0-r (8.111%)        SPM-t0-g (7.745%)
# feature-rank=4   SPM-tau-fall-r (7.524%)      SPM-beta-r (7.466%)
# feature-rank=5       SPM-beta-r (6.454%)  SPM-tau-fall-r (7.108%)
# feature-rank=6   SPM-tau-fall-g (5.135%)     SPM-gamma-g (5.972%)
# feature-rank=7   SPM-tau-rise-r (5.118%)  SPM-tau-rise-r (5.860%)
# feature-rank=8       SPM-beta-g (5.101%)  SPM-tau-fall-g (4.474%)
# feature-rank=9      SPM-gamma-g (4.761%)   LinearTrend-g (4.314%)
# feature-rank=10   LinearTrend-g (4.009%)      SPM-beta-g (3.924%)
# feature-rank=11   LinearTrend-r (3.037%)  SPM-tau-rise-g (3.838%)
# feature-rank=12       IAR-phi-r (2.804%)       IAR-phi-r (3.435%)
# feature-rank=13  SPM-tau-rise-g (2.797%)   LinearTrend-r (3.168%)
# feature-rank=14       IAR-phi-g (2.681%)       IAR-phi-g (3.165%)
# feature-rank=15      MHPS-low-g (2.528%)      MHPS-low-r (2.693%)
