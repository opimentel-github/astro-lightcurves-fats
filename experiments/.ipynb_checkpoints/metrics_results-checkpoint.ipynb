# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import search_for_filedirs, gather_files_by_kfold
from flamingchoripan.cuteplots.cm_plots import plot_custom_confusion_matrix
import matplotlib.pyplot as plt
from flamingchoripan.datascience.xerror import XError
from IPython.display import display

def get_kf_text(set_name, kf):
    if kf=='.':
        return f'($\\mu\\pm\\sigma$ from 5-fold cross-validation in {set_name}-set)'
    else:
        return f'($\\mu\\pm\\sigma$ from {kf} k-fold in {set_name}-set)'

def get_mode_text(mode, features):
    if mode=='sne':
        return f'Using {len(features)} SNe selected astrophysical features'
    else:
        return f'Using {len(features)} astrophysical features'
    
mode = 'sne' # sne all
methods = [
    'linear-fstw',
    'bspline-fstw',
    #'spm-mle-fstw',
    'spm-mcmc-fstw',
    #'spm-mle-estw',
    'spm-mcmc-estw',
]
#methods = ['spm-mcmc-estw']
eval_lcset_name = 'test'
kf = '0'

for method in methods:
    print('='*30+method)
    #for train_config in ['r', 's']:
    for train_config in ['r', 's', 'r+s']:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        features = files[0]()['features']
        cms = np.concatenate([f()['cm'][None] for f in files], axis=0)
        bprecision_xe = XError([f()['metrics_dict']['b-precision'] for f in files])
        brecall_xe = XError([f()['metrics_dict']['b-recall'] for f in files])
        bf1score_xe = XError([f()['metrics_dict']['b-f1score'] for f in files])

        ### plot cm
        _title = 'no-method [r]' if train_config=='r' else f'{method} [{train_config}]'
        title = ''
        title += f'features-mode={mode}'+'\n'
        title += f'train-set={_title} - eval-set={kf}@{eval_lcset_name}'+'\n'
        #title += f'b-p/r={bprecision_xe} / {brecall_xe}'+'\n'
        title += f'b-f1score={bf1score_xe}'+'\n'
        cm_kwargs = {
            'title':title[:-1],
            'figsize':(6,5),
            'new_order_classes':['SNIa', 'SNIbc', 'SNII-b-n', 'SLSN'],
        }
        fig, ax, cm_norm = plot_custom_confusion_matrix(cms, class_names, **cm_kwargs)
        #accu = XError(np.diagonal(cm_norm*100, axis1=1, axis2=2).flatten().tolist())
        #title += f'b-accu={accu}'+'\n'
        #ax.set_title(title[:-1])
        #print(files[0]()['features'])
        caption = ''
        caption += f'Confusion matrix.'
        caption += f' {get_mode_text(mode, features)} {get_kf_text(eval_lcset_name, kf)}'
        print(caption)
        plt.show()
        #assert 0
        print(class_names)
        print(files[0]()['rank'])
        df = files[0]()['wrongs_df']
        #display(df[df['_y']==0])
        #display(df[df['_y']==2])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ==============================linear-fstw
# Confusion matrix. Using 26 SNe selected astrophysical features ($\mu\pm\sigma$ from 0 k-fold in test-set)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.0863
# [2#] SPM_gamma_r=.0714
# [3#] LinearTrend_g=.0657
# [4#] SPM_t0_r=.0637
# [5#] LinearTrend_r=.0583
# [6#] SPM_tau_fall_r=.0564
# [7#] SPM_beta_r=.0559
# [8#] SPM_tau_rise_r=.0480
# [9#] SPM_tau_fall_g=.0444
# [10#] SPM_gamma_g=.0429
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a9f1becdd029> in <module>
#      38     for train_config in ['r', 's', 'r+s']:
#      39         rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
# ---> 40         files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
#      41         class_names = files[0]()['lcset_info']['class_names']
#      42         features = files[0]()['features']
#
# ~/tesis/flaming-choripan/flamingchoripan/files.py in gather_files_by_kfold(rootdir, kf, kf_set, id_key, key_key_separator, key_value_separator, fext, kf_str, create_dir)
#     441
#     442         else:
# --> 443                 kfrd = kfold_rootdirs_dict[kf_set][str(kf)]
#     444 		files, files_ids = gather_files_by_id(kfrd,
#     445                         id_key,
#
# KeyError: 'test'

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

dmetrics = {
    f'b-precision':{'k':1, 'mn':None},
    f'b-recall':{'k':1, 'mn':None},
    f'b-f1score':{'k':1, 'mn':None},
    #f'b-rocauc':{'k':1, 'mn':'b-AUCROC'},
    #f'b-prauc':{'k':1, 'mn':'b-AUCPR'},
    }
info_df = DFBuilder()
for train_config in ['r', 's', 'r+s']:
    aux_r = []
    for method in methods:
        d = {}
        for metric in dmetrics.keys():
            mn = metric if dmetrics[metric]['mn'] is None else dmetrics[metric]['mn']
            rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
            files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
            class_names = files[0]()['lcset_info']['class_names']
            features = files[0]()['features']
            metric_xe = XError([f()['metrics_dict'][metric]*dmetrics[metric]['k'] for f in files])
            d[mn] = metric_xe
            #print(len(metric_xe))
        
        if not train_config=='r': # mean across methods in real case
            info_df.append(f'synthetic-method={method} [{train_config}]', d)
        else:
            aux_r.append(d)

    if train_config=='r': # mean across methods in real case
        new_d = {k:sum([r[k] for r in aux_r]) for k in d.keys()}
        info_df.append(f'synthetic-method=no-method [{train_config}]', new_d)
            
display(info_df())
caption = ''
caption += f'Synthetic generation methods scores using only real samples [r], only synthetic samples [s], and the same proportion of real and synthetic samples [r+s].'
caption += f' {get_mode_text(mode, features)} {get_kf_text(eval_lcset_name, kf)}'

latex_kwargs = {
    'caption':caption,
    'label':'?',
    #'bold_axis':'columns',
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#                                      b-precision   b-recall  b-f1score
# synthetic-method=no-method [r]         .555±.017  .571±.026  .558±.020
# synthetic-method=linear-fstw [s]       .501±.006  .590±.013  .498±.009
# synthetic-method=bspline-fstw [s]      .493±.010  .585±.025  .475±.012
# synthetic-method=spm-mcmc-fstw [s]     .501±.009  .609±.014  .500±.009
# synthetic-method=spm-mcmc-estw [s]     .514±.004  .620±.007  .523±.003
# synthetic-method=linear-fstw [r+s]     .527±.005  .604±.012  .530±.007
# synthetic-method=bspline-fstw [r+s]    .536±.009  .597±.009  .534±.009
# synthetic-method=spm-mcmc-fstw [r+s]   .522±.008  .617±.014  .529±.009
# synthetic-method=spm-mcmc-estw [r+s]   .538±.006  .614±.016  .545±.009
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{Synthetic generation methods scores using only real samples [r], only synthetic samples [s], and the same proportion of real and synthetic samples [r+s]. Using 26 SNe selected astrophysical features ($\mu\pm\sigma$ from 0 k-fold in test-set)}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|ccc}
# \hline
# synthetic-method & b-precision & b-recall & b-f1score \srule\\\hline\hline
# no-method [r] & .555$\pm$.017 & .571$\pm$.026 & .558$\pm$.020  \srule\\
# linear-fstw [s] & .501$\pm$.006 & .590$\pm$.013 & .498$\pm$.009  \srule\\
# bspline-fstw [s] & .493$\pm$.010 & .585$\pm$.025 & .475$\pm$.012  \srule\\
# spm-mcmc-fstw [s] & .501$\pm$.009 & .609$\pm$.014 & .500$\pm$.009  \srule\\
# spm-mcmc-estw [s] & .514$\pm$.004 & .620$\pm$.007 & .523$\pm$.003  \srule\\
# linear-fstw [r+s] & .527$\pm$.005 & .604$\pm$.012 & .530$\pm$.007  \srule\\
# bspline-fstw [r+s] & .536$\pm$.009 & .597$\pm$.009 & .534$\pm$.009  \srule\\
# spm-mcmc-fstw [r+s] & .522$\pm$.008 & .617$\pm$.014 & .529$\pm$.009  \srule\\
# spm-mcmc-estw [r+s] & .538$\pm$.006 & .614$\pm$.016 & .545$\pm$.009  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

info_df = DFBuilder()
train_config = 'r+s' # r s r+s
rank_n = 15
for k in range(0, rank_n):
    d = {}
    for method in methods:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        features = files[0]()['features']
        rank = files[0]()['rank'] # just show one
        feature_name, feature_p,_ = rank[k]
        feature_name = feature_name.replace('_', '-')
        d[f'{method} [{train_config}]'] = f'{feature_name} ({feature_p*100:.2f}%)'

    info_df.append(f'k={k+1}', d)

caption = ''
caption += f'Random Forest astrophysical features ranking (top {rank_n}) using the same proportion of real and synthetic samples [r+s].'
caption += f' {get_mode_text(mode, features)}.'

latex_kwargs = {
    'caption':caption,
    'label':'?',
    #'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{Random Forest astrophysical features ranking (top 15) using the same proportion of real and synthetic samples [r+s]. Using 26 SNe selected astrophysical features.}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|cccc}
# \hline
# k & linear-fstw [r+s] & bspline-fstw [r+s] & spm-mcmc-fstw [r+s] & spm-mcmc-estw [r+s] \srule\\\hline\hline
# 1 & SPM-t0-g (8.94\%) & SPM-t0-g (8.54\%) & SPM-t0-g (8.95\%) & SPM-t0-g (9.09\%)  \srule\\
# 2 & LinearTrend-g (7.51\%) & LinearTrend-g (8.41\%) & LinearTrend-g (7.61\%) & LinearTrend-g (6.77\%)  \srule\\
# 3 & SPM-t0-r (6.55\%) & LinearTrend-r (6.48\%) & SPM-t0-r (6.73\%) & SPM-t0-r (6.46\%)  \srule\\
# 4 & LinearTrend-r (5.79\%) & SPM-t0-r (6.08\%) & SPM-gamma-r (6.09\%) & SPM-gamma-r (6.18\%)  \srule\\
# 5 & SPM-gamma-r (5.56\%) & SPM-gamma-r (5.33\%) & LinearTrend-r (5.75\%) & LinearTrend-r (5.52\%)  \srule\\
# 6 & SPM-tau-rise-r (5.50\%) & SPM-tau-rise-r (5.20\%) & SPM-tau-rise-r (5.36\%) & SPM-tau-rise-r (5.23\%)  \srule\\
# 7 & SPM-beta-r (5.49\%) & SPM-gamma-g (5.02\%) & SPM-beta-r (4.98\%) & SPM-tau-fall-r (5.00\%)  \srule\\
# 8 & SPM-tau-fall-r (5.17\%) & SPM-tau-fall-g (4.58\%) & SPM-tau-fall-r (4.97\%) & SPM-beta-r (4.92\%)  \srule\\
# 9 & SPM-tau-fall-g (4.65\%) & SPM-beta-r (4.27\%) & SPM-tau-fall-g (4.48\%) & SPM-tau-fall-g (4.58\%)  \srule\\
# 10 & SPM-gamma-g (4.15\%) & SPM-tau-fall-r (3.55\%) & SPM-gamma-g (4.01\%) & SPM-gamma-g (4.38\%)  \srule\\
# 11 & SPM-beta-g (3.42\%) & SPM-beta-g (3.48\%) & SPM-beta-g (3.87\%) & SPM-beta-g (3.81\%)  \srule\\
# 12 & SPM-tau-rise-g (3.09\%) & MHPS-low-r (3.38\%) & MHPS-low-r (2.98\%) & MHPS-ratio-g (3.34\%)  \srule\\
# 13 & SPM-A-g (2.98\%) & IAR-phi-g (3.05\%) & SPM-tau-rise-g (2.97\%) & MHPS-low-r (3.02\%)  \srule\\
# 14 & MHPS-ratio-g (2.89\%) & SPM-tau-rise-g (2.96\%) & SPM-A-g (2.94\%) & SPM-tau-rise-g (2.94\%)  \srule\\
# 15 & MHPS-low-r (2.86\%) & MHPS-ratio-g (2.95\%) & MHPS-ratio-g (2.93\%) & IAR-phi-g (2.93\%)  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#            linear-fstw [r+s]      bspline-fstw [r+s]     spm-mcmc-fstw [r+s]  \
# k=1         SPM-t0-g (8.94%)        SPM-t0-g (8.54%)        SPM-t0-g (8.95%)
# k=2    LinearTrend-g (7.51%)   LinearTrend-g (8.41%)   LinearTrend-g (7.61%)
# k=3         SPM-t0-r (6.55%)   LinearTrend-r (6.48%)        SPM-t0-r (6.73%)
# k=4    LinearTrend-r (5.79%)        SPM-t0-r (6.08%)     SPM-gamma-r (6.09%)
# k=5      SPM-gamma-r (5.56%)     SPM-gamma-r (5.33%)   LinearTrend-r (5.75%)
# k=6   SPM-tau-rise-r (5.50%)  SPM-tau-rise-r (5.20%)  SPM-tau-rise-r (5.36%)
# k=7       SPM-beta-r (5.49%)     SPM-gamma-g (5.02%)      SPM-beta-r (4.98%)
# k=8   SPM-tau-fall-r (5.17%)  SPM-tau-fall-g (4.58%)  SPM-tau-fall-r (4.97%)
# k=9   SPM-tau-fall-g (4.65%)      SPM-beta-r (4.27%)  SPM-tau-fall-g (4.48%)
# k=10     SPM-gamma-g (4.15%)  SPM-tau-fall-r (3.55%)     SPM-gamma-g (4.01%)
# k=11      SPM-beta-g (3.42%)      SPM-beta-g (3.48%)      SPM-beta-g (3.87%)
# k=12  SPM-tau-rise-g (3.09%)      MHPS-low-r (3.38%)      MHPS-low-r (2.98%)
# k=13         SPM-A-g (2.98%)       IAR-phi-g (3.05%)  SPM-tau-rise-g (2.97%)
# k=14    MHPS-ratio-g (2.89%)  SPM-tau-rise-g (2.96%)         SPM-A-g (2.94%)
# k=15      MHPS-low-r (2.86%)    MHPS-ratio-g (2.95%)    MHPS-ratio-g (2.93%)
#
#          spm-mcmc-estw [r+s]
# k=1         SPM-t0-g (9.09%)
# k=2    LinearTrend-g (6.77%)
# k=3         SPM-t0-r (6.46%)
# k=4      SPM-gamma-r (6.18%)
# k=5    LinearTrend-r (5.52%)
# k=6   SPM-tau-rise-r (5.23%)
# k=7   SPM-tau-fall-r (5.00%)
# k=8       SPM-beta-r (4.92%)
# k=9   SPM-tau-fall-g (4.58%)
# k=10     SPM-gamma-g (4.38%)
# k=11      SPM-beta-g (3.81%)
# k=12    MHPS-ratio-g (3.34%)
# k=13      MHPS-low-r (3.02%)
# k=14  SPM-tau-rise-g (2.94%)
# k=15       IAR-phi-g (2.93%)

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

dmetrics = {
    f'b-precision':{'k':1, 'mn':None},
    f'b-recall':{'k':1, 'mn':None},
    f'b-f1score':{'k':1, 'mn':None},
    #f'b-rocauc':{'k':1, 'mn':'b-ROCAUC'},
    #f'b-prauc':{'k':1, 'mn':'b-PRAUC'},
    }
info_df = DFBuilder()
for metric in dmetrics.keys():
    for train_config in ['r', 's', 'r+s']:
    #for train_config in ['r', 's']:
        d = {}
        for method in methods:
            rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
            files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
            metric_xe = XError([f()['metrics_dict'][metric]*dmetrics[metric]['k'] for f in files])
            d[method] = metric_xe
            #print(len(metric_xe))
        
        if train_config=='r': # mean across methods in real case
            new_metric_xe = sum([d[k] for k in d.keys()])
            fstw_n = sum([m.split('-')[-1]=='fstw' for m in methods])
            fste_n = sum([m.split('-')[-1]=='estw' for m in methods])
            print('\\multicolumn{'+str(fstw_n)+'}{c|}{'+str(new_metric_xe).replace('±', '$\\pm$')+'}'+'& --'*fste_n+'\\srule\\\\')
            d = {k:new_metric_xe for k in d.keys()}
            
        mn = dmetrics[metric]['mn']
        info_df.append(f'metric={metric if mn is None else mn} [{train_config}]', d)

display(info_df())
caption = ''
caption += f'Synthetic generation methods scores using only real samples [r], only synthetic samples [s], and the same proportion of real and synthetic samples [r+s].'
caption += f' {get_mode_text(mode)} {get_kf_text(eval_lcset_name, kf)}'

latex_kwargs = {
    'caption':caption,
    'label':'?',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# \multicolumn{3}{c|}{.555$\pm$.017}& --\srule\\
# \multicolumn{3}{c|}{.571$\pm$.026}& --\srule\\
# \multicolumn{3}{c|}{.558$\pm$.020}& --\srule\\
#                          linear-fstw bspline-fstw spm-mcmc-fstw spm-mcmc-estw
# metric=b-precision [r]     .555±.017    .555±.017     .555±.017     .555±.017
# metric=b-precision [s]     .501±.006    .493±.010     .501±.009     .514±.004
# metric=b-precision [r+s]   .527±.005    .536±.009     .522±.008     .538±.006
# metric=b-recall [r]        .571±.026    .571±.026     .571±.026     .571±.026
# metric=b-recall [s]        .590±.013    .585±.025     .609±.014     .620±.007
# metric=b-recall [r+s]      .604±.012    .597±.009     .617±.014     .614±.016
# metric=b-f1score [r]       .558±.020    .558±.020     .558±.020     .558±.020
# metric=b-f1score [s]       .498±.009    .475±.012     .500±.009     .523±.003
# metric=b-f1score [r+s]     .530±.007    .534±.009     .529±.009     .545±.009
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4eec73e98fea> in <module>
#      39 caption = ''
#      40 caption += f'Synthetic generation methods scores using only real samples [r], only synthetic samples [s], and the same proportion of real and synthetic samples [r+s].'
# ---> 41 caption += f' {get_mode_text(mode)} {get_kf_text(eval_lcset_name, kf)}'
#      42
#      43 latex_kwargs = {
#
# TypeError: get_mode_text() missing 1 required positional argument: 'features'
