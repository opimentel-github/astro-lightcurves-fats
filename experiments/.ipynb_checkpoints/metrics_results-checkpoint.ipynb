# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import search_for_filedirs, gather_files_by_kfold
from flamingchoripan.cuteplots.cm_plots import plot_custom_confusion_matrix
import matplotlib.pyplot as plt
from flamingchoripan.datascience.xerror import XError
from IPython.display import display

mode = 'sne' # all sne
methods = [
    'linear-fstw',
    'bspline-fstw',
    #'spm-mle-fstw',
    'spm-mcmc-fstw',
    #'spm-mle-estw',
    'spm-mcmc-estw',
]
#methods = ['spm-mcmc-estw']
eval_lcset_name = 'test' # val test
kf = '.'

for method in methods:
    print('='*30+method)
    #for train_config in ['r', 's']:
    for train_config in ['r', 's', 'r+s']:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        cms = np.concatenate([f()['cm'][None] for f in files], axis=0)
        f1score_xe = XError([f()['metrics_dict']['b-f1score'] for f in files])
        accuracy_xe = XError([f()['metrics_dict']['b-accuracy'] for f in files])
        print(cms.shape)

        ### plot cm
        _title = 'no-method [r]' if train_config=='r' else f'{method} [{train_config}]'
        title = ''
        title += f'train set={_title} - eval={kf}@{eval_lcset_name}'+'\n'
        title += f'b-f1score={f1score_xe}'+'\n'
        title += f'b-accuracy={accuracy_xe}%'+'\n'
        cm_kwargs = {
            'title':title[:-1],
            'figsize':(6,5),
            'new_order_classes':['SNIa', 'SNIbc', 'SNII-b-n', 'SLSN'],
        }
        fig, ax = plot_custom_confusion_matrix(cms, class_names, **cm_kwargs)
        #print(files[0]()['features'])
        plt.show()
        print(class_names)
        print(files[0]()['rank'])
        df = files[0]()['wrongs_df']
        #display(df[df['_y']==0])
        #display(df[df['_y']==2])
# Out:
# ==============================linear-fstw
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1123
# [2#] LinearTrend_g=.0959
# [3#] SPM_gamma_r=.0792
# [4#] SPM_t0_r=.0711
# [5#] LinearTrend_r=.0649
# [6#] SPM_tau_rise_r=.0563
# [7#] SPM_tau_fall_r=.0547
# [8#] SPM_tau_fall_g=.0495
# [9#] SPM_gamma_g=.0424
# [10#] MHPS_high_r=.0307
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.2193
# [2#] SPM_tau_rise_r=.0878
# [3#] SPM_tau_fall_r=.0639
# [4#] SPM_gamma_r=.0472
# [5#] LinearTrend_g=.0409
# [6#] SPM_tau_fall_g=.0397
# [7#] SPM_t0_r=.0378
# [8#] LinearTrend_r=.0378
# [9#] SPM_gamma_g=.0293
# [10#] MHPS_high_g=.0275
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1825
# [2#] SPM_tau_fall_r=.0764
# [3#] SPM_gamma_r=.0666
# [4#] SPM_tau_rise_r=.0586
# [5#] LinearTrend_g=.0573
# [6#] SPM_t0_r=.0472
# [7#] SPM_tau_fall_g=.0441
# [8#] LinearTrend_r=.0388
# [9#] SPM_gamma_g=.0320
# [10#] MHPS_high_g=.0263
# ==============================bspline-fstw
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1152
# [2#] LinearTrend_g=.0954
# [3#] SPM_gamma_r=.0803
# [4#] SPM_t0_r=.0668
# [5#] LinearTrend_r=.0652
# [6#] SPM_tau_rise_r=.0602
# [7#] SPM_tau_fall_r=.0534
# [8#] SPM_tau_fall_g=.0517
# [9#] SPM_gamma_g=.0395
# [10#] MHPS_high_r=.0288
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.2018
# [2#] SPM_tau_rise_r=.0925
# [3#] LinearTrend_g=.0543
# [4#] SPM_gamma_r=.0396
# [5#] MHPS_high_g=.0359
# [6#] MHPS_non_zero_r=.0328
# [7#] SPM_gamma_g=.0324
# [8#] SPM_tau_rise_g=.0323
# [9#] SPM_t0_r=.0309
# [10#] SPM_tau_fall_g=.0305
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1660
# [2#] LinearTrend_g=.0715
# [3#] SPM_tau_rise_r=.0665
# [4#] SPM_gamma_r=.0547
# [5#] SPM_tau_fall_g=.0451
# [6#] SPM_t0_r=.0430
# [7#] SPM_tau_fall_r=.0385
# [8#] SPM_gamma_g=.0380
# [9#] LinearTrend_r=.0369
# [10#] MHPS_low_r=.0323
# ==============================spm-mcmc-fstw
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1100
# [2#] LinearTrend_g=.0954
# [3#] SPM_gamma_r=.0795
# [4#] SPM_t0_r=.0712
# [5#] LinearTrend_r=.0687
# [6#] SPM_tau_rise_r=.0559
# [7#] SPM_tau_fall_r=.0555
# [8#] SPM_tau_fall_g=.0536
# [9#] SPM_gamma_g=.0381
# [10#] MHPS_high_r=.0311
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1980
# [2#] SPM_gamma_r=.0794
# [3#] SPM_tau_fall_r=.0644
# [4#] SPM_tau_rise_r=.0594
# [5#] LinearTrend_g=.0464
# [6#] SPM_t0_r=.0442
# [7#] SPM_tau_fall_g=.0377
# [8#] SF_ML_amplitude_r=.0337
# [9#] SPM_gamma_g=.0298
# [10#] LinearTrend_r=.0292
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1791
# [2#] SPM_gamma_r=.0793
# [3#] SPM_tau_fall_r=.0705
# [4#] LinearTrend_g=.0586
# [5#] SPM_tau_rise_r=.0518
# [6#] SPM_t0_r=.0441
# [7#] SPM_tau_fall_g=.0411
# [8#] LinearTrend_r=.0304
# [9#] SPM_gamma_g=.0300
# [10#] SPM_A_g=.0272
# ==============================spm-mcmc-estw
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1077
# [2#] LinearTrend_g=.0917
# [3#] SPM_gamma_r=.0814
# [4#] SPM_t0_r=.0712
# [5#] LinearTrend_r=.0679
# [6#] SPM_tau_fall_r=.0550
# [7#] SPM_tau_rise_r=.0544
# [8#] SPM_tau_fall_g=.0518
# [9#] SPM_gamma_g=.0440
# [10#] MHPS_high_r=.0299
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.2127
# [2#] SPM_tau_rise_r=.0755
# [3#] SPM_tau_fall_r=.0713
# [4#] LinearTrend_g=.0644
# [5#] SPM_gamma_r=.0565
# [6#] SPM_tau_fall_g=.0379
# [7#] GP_DRW_sigma_r=.0287
# [8#] MHPS_high_g=.0276
# [9#] SPM_A_r=.0264
# [10#] LinearTrend_r=.0257
# (50, 4, 4)
# ['SLSN', 'SNII-b-n', 'SNIa', 'SNIbc']
# features:
# [1#] SPM_t0_g=.1897
# [2#] SPM_tau_fall_r=.0727
# [3#] LinearTrend_g=.0693
# [4#] SPM_gamma_r=.0690
# [5#] SPM_tau_rise_r=.0589
# [6#] SPM_tau_fall_g=.0432
# [7#] SPM_t0_r=.0295
# [8#] LinearTrend_r=.0294
# [9#] SPM_gamma_g=.0279
# [10#] MHPS_low_r=.0253

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

metrics = [
    'b-accuracy',
    'b-f1score',
    'b-gmean',
    #'b-dpower',
    'b-xentropy',
]
info_df = DFBuilder()
for metric in metrics:
    for train_config in ['r', 's', 'r+s']:
    #for train_config in ['r', 's']:
        d = {}
        for method in methods:
            rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
            files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
            metric_xe = XError([f()['metrics_dict'][metric] for f in files])
            d[method] = metric_xe
            #print(len(metric_xe))

        info_df.append(f'metric={metric} [{train_config}]', d)
        
latex_kwargs = {
    'caption':f'eval-set={kf}@{eval_lcset_name}',
    'label':'?',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
print('% \multicolumn{3}{c|}{}')
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{eval-set=.@test}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|ccc|c}
# \hline
# metric & linear-fstw & bspline-fstw & spm-mcmc-fstw & spm-mcmc-estw \srule\\\hline\hline
# b-accuracy [r] & 61.323$\pm$3.371 & 61.271$\pm$3.266 & 61.174$\pm$3.254 & 61.497$\pm$3.197  \srule\\
# b-accuracy [s] & 63.285$\pm$5.872 & 56.499$\pm$5.861 & 62.951$\pm$5.129 & 62.495$\pm$5.787  \srule\\
# b-accuracy [r+s] & 63.650$\pm$7.207 & 61.608$\pm$7.196 & 64.903$\pm$6.379 & 64.262$\pm$6.983  \srule\\
# \hline
# b-f1score [r] & .459$\pm$.010 & .460$\pm$.008 & .459$\pm$.009 & .462$\pm$.010  \srule\\
# b-f1score [s] & .510$\pm$.038 & .478$\pm$.040 & .515$\pm$.038 & .510$\pm$.036  \srule\\
# b-f1score [r+s] & .546$\pm$.040 & .546$\pm$.046 & .556$\pm$.044 & .552$\pm$.048  \srule\\
# \hline
# b-gmean [r] & .732$\pm$.021 & .732$\pm$.020 & .731$\pm$.021 & .733$\pm$.020  \srule\\
# b-gmean [s] & .748$\pm$.043 & .691$\pm$.046 & .746$\pm$.036 & .742$\pm$.041  \srule\\
# b-gmean [r+s] & .746$\pm$.053 & .729$\pm$.056 & .757$\pm$.047 & .753$\pm$.051  \srule\\
# \hline
# b-xentropy [r] & .998$\pm$.049 & .999$\pm$.049 & .999$\pm$.049 & .999$\pm$.050  \srule\\
# b-xentropy [s] & .972$\pm$.128 & 1.060$\pm$.155 & .953$\pm$.105 & 1.031$\pm$.172  \srule\\
# b-xentropy [r+s] & .975$\pm$.103 & 1.016$\pm$.129 & .957$\pm$.094 & 1.013$\pm$.135  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# % \multicolumn{3}{c|}{}
#                           linear-fstw  bspline-fstw spm-mcmc-fstw  \
# metric=b-accuracy [r]    61.323±3.371  61.271±3.266  61.174±3.254
# metric=b-accuracy [s]    63.285±5.872  56.499±5.861  62.951±5.129
# metric=b-accuracy [r+s]  63.650±7.207  61.608±7.196  64.903±6.379
# metric=b-f1score [r]        .459±.010     .460±.008     .459±.009
# metric=b-f1score [s]        .510±.038     .478±.040     .515±.038
# metric=b-f1score [r+s]      .546±.040     .546±.046     .556±.044
# metric=b-gmean [r]          .732±.021     .732±.020     .731±.021
# metric=b-gmean [s]          .748±.043     .691±.046     .746±.036
# metric=b-gmean [r+s]        .746±.053     .729±.056     .757±.047
# metric=b-xentropy [r]       .998±.049     .999±.049     .999±.049
# metric=b-xentropy [s]       .972±.128    1.060±.155     .953±.105
# metric=b-xentropy [r+s]     .975±.103    1.016±.129     .957±.094
#
#                         spm-mcmc-estw
# metric=b-accuracy [r]    61.497±3.197
# metric=b-accuracy [s]    62.495±5.787
# metric=b-accuracy [r+s]  64.262±6.983
# metric=b-f1score [r]        .462±.010
# metric=b-f1score [s]        .510±.036
# metric=b-f1score [r+s]      .552±.048
# metric=b-gmean [r]          .733±.020
# metric=b-gmean [s]          .742±.041
# metric=b-gmean [r+s]        .753±.051
# metric=b-xentropy [r]       .999±.050
# metric=b-xentropy [s]      1.031±.172
# metric=b-xentropy [r+s]    1.013±.135

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

info_df = DFBuilder()
train_config = 'r+s' # r s r+s
rank_n = 10
for k in range(0, rank_n):
    d = {}
    for method in methods:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}~mode={mode}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        rank = files[0]()['rank']
        #print(rank)
        feature_name, feature_p,_ = rank[k]
        feature_name = feature_name.replace('_', '-')
        d[f'{method} [{train_config}]'] = f'{feature_name} ({feature_p*100:.3f}%)'

    info_df.append(f'rank={k+1}', d)

latex_kwargs = {
    'caption':f'eval-set={kf}@{eval_lcset_name}',
    'label':'?',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    #'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{eval-set=.@test}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|ccc|c}
# \hline
# rank & linear-fstw [r+s] & bspline-fstw [r+s] & spm-mcmc-fstw [r+s] & spm-mcmc-estw [r+s] \srule\\\hline\hline
# 1 & SPM-t0-g (18.254\%) & SPM-t0-g (16.603\%) & SPM-t0-g (17.918\%) & SPM-t0-g (18.977\%)  \srule\\
# 2 & SPM-tau-fall-r (7.647\%) & LinearTrend-g (7.156\%) & SPM-gamma-r (7.934\%) & SPM-tau-fall-r (7.279\%)  \srule\\
# 3 & SPM-gamma-r (6.666\%) & SPM-tau-rise-r (6.660\%) & SPM-tau-fall-r (7.053\%) & LinearTrend-g (6.931\%)  \srule\\
# 4 & SPM-tau-rise-r (5.865\%) & SPM-gamma-r (5.472\%) & LinearTrend-g (5.862\%) & SPM-gamma-r (6.902\%)  \srule\\
# 5 & LinearTrend-g (5.736\%) & SPM-tau-fall-g (4.520\%) & SPM-tau-rise-r (5.186\%) & SPM-tau-rise-r (5.900\%)  \srule\\
# 6 & SPM-t0-r (4.726\%) & SPM-t0-r (4.307\%) & SPM-t0-r (4.412\%) & SPM-tau-fall-g (4.327\%)  \srule\\
# 7 & SPM-tau-fall-g (4.417\%) & SPM-tau-fall-r (3.851\%) & SPM-tau-fall-g (4.112\%) & SPM-t0-r (2.954\%)  \srule\\
# 8 & LinearTrend-r (3.882\%) & SPM-gamma-g (3.807\%) & LinearTrend-r (3.048\%) & LinearTrend-r (2.942\%)  \srule\\
# 9 & SPM-gamma-g (3.209\%) & LinearTrend-r (3.691\%) & SPM-gamma-g (3.004\%) & SPM-gamma-g (2.793\%)  \srule\\
# 10 & MHPS-high-g (2.633\%) & MHPS-low-r (3.235\%) & SPM-A-g (2.724\%) & MHPS-low-r (2.537\%)  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                linear-fstw [r+s]       bspline-fstw [r+s]  \
# rank=1        SPM-t0-g (18.254%)       SPM-t0-g (16.603%)
# rank=2   SPM-tau-fall-r (7.647%)   LinearTrend-g (7.156%)
# rank=3      SPM-gamma-r (6.666%)  SPM-tau-rise-r (6.660%)
# rank=4   SPM-tau-rise-r (5.865%)     SPM-gamma-r (5.472%)
# rank=5    LinearTrend-g (5.736%)  SPM-tau-fall-g (4.520%)
# rank=6         SPM-t0-r (4.726%)        SPM-t0-r (4.307%)
# rank=7   SPM-tau-fall-g (4.417%)  SPM-tau-fall-r (3.851%)
# rank=8    LinearTrend-r (3.882%)     SPM-gamma-g (3.807%)
# rank=9      SPM-gamma-g (3.209%)   LinearTrend-r (3.691%)
# rank=10     MHPS-high-g (2.633%)      MHPS-low-r (3.235%)
#
#              spm-mcmc-fstw [r+s]      spm-mcmc-estw [r+s]
# rank=1        SPM-t0-g (17.918%)       SPM-t0-g (18.977%)
# rank=2      SPM-gamma-r (7.934%)  SPM-tau-fall-r (7.279%)
# rank=3   SPM-tau-fall-r (7.053%)   LinearTrend-g (6.931%)
# rank=4    LinearTrend-g (5.862%)     SPM-gamma-r (6.902%)
# rank=5   SPM-tau-rise-r (5.186%)  SPM-tau-rise-r (5.900%)
# rank=6         SPM-t0-r (4.412%)  SPM-tau-fall-g (4.327%)
# rank=7   SPM-tau-fall-g (4.112%)        SPM-t0-r (2.954%)
# rank=8    LinearTrend-r (3.048%)   LinearTrend-r (2.942%)
# rank=9      SPM-gamma-g (3.004%)     SPM-gamma-g (2.793%)
# rank=10         SPM-A-g (2.724%)      MHPS-low-r (2.537%)
