# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import search_for_filedirs, gather_files_by_kfold
from flamingchoripan.cuteplots.cm_plots import plot_custom_confusion_matrix
import matplotlib.pyplot as plt
from flamingchoripan.datascience.xerror import XError
from IPython.display import display

methods = [
    'linear-fstw',
    'bspline-fstw',
    #'spm-mle-fstw',
    'spm-mcmc-fstw',
    #'spm-mle-estw',
    'spm-mcmc-estw',
]
#methods = ['spm-mcmc-estw']
eval_lcset_name = 'test' # val test
kf = '.'

for method in methods:
    print('='*30+method)
    #for train_config in ['r', 's']:
    for train_config in ['r', 's', 'r+s']:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        class_names = files[0]()['lcset_info']['class_names']
        cms = np.concatenate([f()['cm'][None] for f in files], axis=0)
        f1score_xe = XError([f()['metrics_dict']['b-f1score'] for f in files])
        accuracy_xe = XError([f()['metrics_dict']['b-accuracy'] for f in files])
        print(cms.shape)

        ### plot cm
        _title = 'no-method [r]' if train_config=='r' else f'{method} [{train_config}]'
        title = ''
        title += f'train set={_title} - eval={kf}@{eval_lcset_name}'+'\n'
        title += f'b-f1score={f1score_xe}'+'\n'
        title += f'b-accuracy={accuracy_xe}%'+'\n'
        cm_kwargs = {
            'title':title[:-1],
            'figsize':(6,5),
            'new_order_classes':['SNIa', 'SNIbc', 'allSNII', 'SLSN'],
        }
        fig, ax = plot_custom_confusion_matrix(cms, class_names, **cm_kwargs)
        #print(files[0]()['features'])
        plt.show()
        print(class_names)
        print(files[0]()['rank'])
        df = files[0]()['wrongs_df']
        #display(df[df['_y']==0])
        #display(df[df['_y']==2])
# Out:
# ==============================linear-fstw
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] Amplitude_g=.0702
# [2#] SPM_t0_g=.0687
# [3#] SPM_gamma_r=.0660
# [4#] SPM_tau_rise_r=.0630
# [5#] Amplitude_r=.0448
# [6#] SPM_gamma_g=.0403
# [7#] SPM_tau_fall_g=.0340
# [8#] SPM_beta_r=.0323
# [9#] SPM_tau_rise_g=.0316
# [10#] SPM_t0_r=.0264
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] SPM_t0_g=.1596
# [2#] SPM_tau_rise_r=.0757
# [3#] LinearTrend_g=.0544
# [4#] SPM_beta_r=.0500
# [5#] SPM_tau_fall_r=.0382
# [6#] SPM_tau_fall_g=.0373
# [7#] SPM_gamma_r=.0315
# [8#] SPM_gamma_g=.0283
# [9#] Meanvariance_r=.0221
# [10#] LinearTrend_r=.0188
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] SPM_t0_g=.1410
# [2#] Amplitude_g=.0728
# [3#] SPM_tau_rise_r=.0582
# [4#] SPM_beta_r=.0530
# [5#] SPM_gamma_r=.0453
# [6#] SPM_tau_fall_r=.0427
# [7#] SPM_tau_fall_g=.0426
# [8#] ExcessVar_r=.0334
# [9#] SPM_gamma_g=.0250
# [10#] MHPS_ratio_g=.0240
# ==============================bspline-fstw
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] SPM_t0_g=.0709
# [2#] SPM_gamma_r=.0675
# [3#] SPM_tau_rise_r=.0671
# [4#] AndersonDarling_g=.0666
# [5#] AndersonDarling_r=.0437
# [6#] SPM_gamma_g=.0426
# [7#] SPM_tau_rise_g=.0354
# [8#] SPM_beta_r=.0327
# [9#] SPM_tau_fall_g=.0294
# [10#] SPM_tau_fall_r=.0284
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] Amplitude_g=.1066
# [2#] SPM_t0_g=.0953
# [3#] SPM_tau_rise_r=.0726
# [4#] ExcessVar_r=.0342
# [5#] MHPS_ratio_g=.0276
# [6#] Amplitude_r=.0273
# [7#] SPM_gamma_r=.0243
# [8#] MHPS_high_g=.0229
# [9#] SPM_gamma_g=.0225
# [10#] SPM_t0_r=.0219
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] AndersonDarling_g=.1132
# [2#] SPM_t0_g=.0769
# [3#] SPM_tau_rise_r=.0579
# [4#] MedianAbsDev_r=.0428
# [5#] AndersonDarling_r=.0361
# [6#] SPM_tau_fall_g=.0358
# [7#] MHPS_ratio_g=.0351
# [8#] SPM_gamma_r=.0315
# [9#] SPM_gamma_g=.0238
# [10#] SPM_tau_fall_r=.0210
# ==============================spm-mcmc-fstw
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] Eta_e_g=.0691
# [2#] SPM_t0_g=.0690
# [3#] SPM_gamma_r=.0673
# [4#] SPM_tau_rise_r=.0614
# [5#] Eta_e_r=.0475
# [6#] SPM_gamma_g=.0366
# [7#] SPM_tau_rise_g=.0356
# [8#] SPM_beta_r=.0331
# [9#] SPM_tau_fall_g=.0285
# [10#] SPM_tau_fall_r=.0261
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] SPM_t0_g=.1042
# [2#] SPM_gamma_r=.0704
# [3#] SPM_tau_rise_r=.0675
# [4#] SPM_beta_r=.0638
# [5#] LinearTrend_g=.0630
# [6#] SPM_t0_r=.0474
# [7#] SPM_tau_fall_r=.0468
# [8#] SPM_tau_fall_g=.0239
# [9#] Meanvariance_r=.0213
# [10#] SPM_gamma_g=.0159
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] SPM_t0_g=.1136
# [2#] Eta_e_g=.0762
# [3#] SPM_gamma_r=.0702
# [4#] SPM_tau_rise_r=.0617
# [5#] SPM_beta_r=.0609
# [6#] SPM_tau_fall_r=.0494
# [7#] SPM_tau_fall_g=.0333
# [8#] Mean_r=.0274
# [9#] MHPS_ratio_g=.0208
# [10#] Eta_e_r=.0202
# ==============================spm-mcmc-estw
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] SPM_t0_g=.0704
# [2#] SPM_gamma_r=.0666
# [3#] LinearTrend_g=.0665
# [4#] SPM_tau_rise_r=.0660
# [5#] LinearTrend_r=.0453
# [6#] SPM_gamma_g=.0405
# [7#] SPM_tau_rise_g=.0360
# [8#] SPM_beta_r=.0341
# [9#] SPM_tau_fall_g=.0320
# [10#] SPM_tau_fall_r=.0283
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] SPM_gamma_r=.1195
# [2#] SPM_tau_rise_r=.0723
# [3#] SPM_t0_g=.0711
# [4#] SPM_beta_r=.0568
# [5#] FluxPercentileRatioMid50_r=.0431
# [6#] SPM_tau_fall_r=.0370
# [7#] SPM_tau_rise_g=.0343
# [8#] SmallKurtosis_g=.0335
# [9#] SPM_t0_r=.0242
# [10#] SPM_tau_fall_g=.0194
# (100, 4, 4)
# ['SLSN', 'SNIa', 'SNIbc', 'allSNII']
# features:
# [1#] SPM_t0_g=.1130
# [2#] SPM_gamma_r=.0881
# [3#] SPM_tau_rise_r=.0583
# [4#] SPM_beta_r=.0549
# [5#] Meanvariance_r=.0488
# [6#] SPM_tau_fall_r=.0419
# [7#] LinearTrend_g=.0401
# [8#] SPM_tau_rise_g=.0280
# [9#] SPM_tau_fall_g=.0251
# [10#] SPM_gamma_g=.0251

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

metrics = [
    'b-accuracy',
    'b-f1score',
    'b-gmean',
    #'b-dpower',
    'b-xentropy',
]
info_df = DFBuilder()
for metric in metrics:
    for train_config in ['r', 's', 'r+s']:
    #for train_config in ['r', 's']:
        d = {}
        for method in methods:
            rootdir = f'../save/exp=rf_eval~train_config={train_config}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
            files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
            metric_xe = XError([f()['metrics_dict'][metric] for f in files])
            d[method] = metric_xe
            #print(len(metric_xe))

        info_df.append(f'metric={metric} [{train_config}]', d)
        
latex_kwargs = {
    'caption':f'eval-set={kf}@{eval_lcset_name}',
    'label':'?',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
print('% \multicolumn{3}{c|}{}')
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.datascience.xerror import XError
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

info_df = DFBuilder()
train_config = 's' # r s r+s
rank_n = 10
for k in range(0, rank_n):
    d = {}
    for method in methods:
        rootdir = f'../save/exp=rf_eval~train_config={train_config}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
        files, files_ids = gather_files_by_kfold(rootdir, kf, eval_lcset_name)
        rank = files[0]()['rank']
        #print(rank)
        feature_name, feature_p,_ = rank[k]
        feature_name = feature_name.replace('_', '-')
        d[f'{method} [{train_config}]'] = f'{feature_name} ({feature_p*100:.3f}%)'

    info_df.append(f'rank={k+1}', d)

latex_kwargs = {
    'caption':f'eval-set={kf}@{eval_lcset_name}',
    'label':'?',
    'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    #'hline_k':2,
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
info_df()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{eval-set=.@test}
# \label{?}\vspace{.1cm}
# \begin{tabular}{l|ccc|c}
# \hline
# rank & linear-fstw [s] & bspline-fstw [s] & spm-mcmc-fstw [s] & spm-mcmc-estw [s] \srule\\\hline\hline
# 1 & SPM-t0-g (15.958\%) & Amplitude-g (10.661\%) & SPM-t0-g (10.418\%) & SPM-gamma-r (11.953\%)  \srule\\
# 2 & SPM-tau-rise-r (7.567\%) & SPM-t0-g (9.531\%) & SPM-gamma-r (7.040\%) & SPM-tau-rise-r (7.226\%)  \srule\\
# 3 & LinearTrend-g (5.436\%) & SPM-tau-rise-r (7.262\%) & SPM-tau-rise-r (6.751\%) & SPM-t0-g (7.111\%)  \srule\\
# 4 & SPM-beta-r (5.000\%) & ExcessVar-r (3.416\%) & SPM-beta-r (6.382\%) & SPM-beta-r (5.678\%)  \srule\\
# 5 & SPM-tau-fall-r (3.819\%) & MHPS-ratio-g (2.762\%) & LinearTrend-g (6.305\%) & FluxPercentileRatioMid50-r (4.309\%)  \srule\\
# 6 & SPM-tau-fall-g (3.729\%) & Amplitude-r (2.728\%) & SPM-t0-r (4.738\%) & SPM-tau-fall-r (3.696\%)  \srule\\
# 7 & SPM-gamma-r (3.149\%) & SPM-gamma-r (2.431\%) & SPM-tau-fall-r (4.678\%) & SPM-tau-rise-g (3.430\%)  \srule\\
# 8 & SPM-gamma-g (2.827\%) & MHPS-high-g (2.286\%) & SPM-tau-fall-g (2.387\%) & SmallKurtosis-g (3.347\%)  \srule\\
# 9 & Meanvariance-r (2.212\%) & SPM-gamma-g (2.246\%) & Meanvariance-r (2.132\%) & SPM-t0-r (2.418\%)  \srule\\
# 10 & LinearTrend-r (1.883\%) & SPM-t0-r (2.191\%) & SPM-gamma-g (1.594\%) & SPM-tau-fall-g (1.936\%)  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                  linear-fstw [s]         bspline-fstw [s]  \
# rank=1        SPM-t0-g (15.958%)    Amplitude-g (10.661%)
# rank=2   SPM-tau-rise-r (7.567%)        SPM-t0-g (9.531%)
# rank=3    LinearTrend-g (5.436%)  SPM-tau-rise-r (7.262%)
# rank=4       SPM-beta-r (5.000%)     ExcessVar-r (3.416%)
# rank=5   SPM-tau-fall-r (3.819%)    MHPS-ratio-g (2.762%)
# rank=6   SPM-tau-fall-g (3.729%)     Amplitude-r (2.728%)
# rank=7      SPM-gamma-r (3.149%)     SPM-gamma-r (2.431%)
# rank=8      SPM-gamma-g (2.827%)     MHPS-high-g (2.286%)
# rank=9   Meanvariance-r (2.212%)     SPM-gamma-g (2.246%)
# rank=10   LinearTrend-r (1.883%)        SPM-t0-r (2.191%)
#
#                spm-mcmc-fstw [s]                    spm-mcmc-estw [s]
# rank=1        SPM-t0-g (10.418%)                SPM-gamma-r (11.953%)
# rank=2      SPM-gamma-r (7.040%)              SPM-tau-rise-r (7.226%)
# rank=3   SPM-tau-rise-r (6.751%)                    SPM-t0-g (7.111%)
# rank=4       SPM-beta-r (6.382%)                  SPM-beta-r (5.678%)
# rank=5    LinearTrend-g (6.305%)  FluxPercentileRatioMid50-r (4.309%)
# rank=6         SPM-t0-r (4.738%)              SPM-tau-fall-r (3.696%)
# rank=7   SPM-tau-fall-r (4.678%)              SPM-tau-rise-g (3.430%)
# rank=8   SPM-tau-fall-g (2.387%)             SmallKurtosis-g (3.347%)
# rank=9   Meanvariance-r (2.132%)                    SPM-t0-r (2.418%)
# rank=10     SPM-gamma-g (1.594%)              SPM-tau-fall-g (1.936%)
