# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
import pandas as pd

rootdir = '../save/alerceZTFv7.1/survey=alerceZTFv7.1°bands=gr°mode=onlySNe°method=linear-fstw'
filedir = f'{rootdir}/train.ftres'
df_xy = pd.read_parquet(filedir) # parquet
df_xy
# Out:
#               SF_ML_amplitude_g   IAR_phi_g  LinearTrend_g   SPM_A_g  \
# ZTF17aadlxmv           0.026272    0.923670      -0.001672  0.339560
# ZTF18aaaqexr           0.836310    0.851545      -0.002378  0.198096
# ZTF18aacdbzx        -999.000000 -999.000000    -999.000000  0.096411
# ZTF18aadmssd          11.993579    0.976337      -0.009397  1.538252
# ZTF18aadzfso           0.075264    0.900336      -0.000555  0.212788
# ...                         ...         ...            ...       ...
# ZTF20abgbiet        -999.000000 -999.000000    -999.000000  0.300228
# ZTF20abgbxfm           0.297794    0.986271      -0.002476  0.242348
# ZTF20abgdtmv           3.435723    0.982925      -0.003913  0.254614
# ZTF20abgfekk           0.722722    0.937964       0.002157  0.448834
# ZTF20abhvnzc           0.474868    0.932487      -0.010708  0.270265
#
#                SPM_t0_g  SPM_gamma_g  SPM_beta_g  SPM_tau_rise_g  \
# ZTF17aadlxmv   5.044085    22.036949    0.650769        2.330068
# ZTF18aaaqexr   0.504443     2.074484    0.112886        1.205324
# ZTF18aacdbzx  -0.339981    28.507677    0.806453        4.456949
# ZTF18aadmssd -21.640165    29.331668    0.772415        5.409822
# ZTF18aadzfso   5.520032     4.068454    0.008352        3.796964
# ...                 ...          ...         ...             ...
# ZTF20abgbiet  -6.008803    24.273772    0.000121       20.157221
# ZTF20abgbxfm   1.313099    29.033773    0.816485        3.196343
# ZTF20abgdtmv   4.288208     7.376943    0.633711        6.301169
# ZTF20abgfekk   5.252328    18.219184    0.269453        3.415261
# ZTF20abhvnzc  -9.159156    15.167689    0.049933       11.146801
#
#               SPM_tau_fall_g   SPM_chi_g  ...  SPM_beta_r  SPM_tau_rise_r  \
# ZTF17aadlxmv       11.606477    0.019497  ...    0.521410        3.627383
# ZTF18aaaqexr       17.585403    0.306611  ...    0.447667        8.598089
# ZTF18aacdbzx       96.885660 -999.000000  ...    0.105452        6.338704
# ZTF18aadmssd       22.131700    0.058958  ...    0.747841       16.252478
# ZTF18aadzfso       14.152086    0.058318  ...    0.610325        3.994414
# ...                      ...         ...  ...         ...             ...
# ZTF20abgbiet        4.275452 -999.000000  ...    0.000768        3.784998
# ZTF20abgbxfm       24.443230    0.084746  ...    0.579473        5.149648
# ZTF20abgdtmv       10.057721    0.023075  ...    0.420425        5.961115
# ZTF20abgfekk       19.974845    0.062150  ...    0.521981        3.882839
# ZTF20abhvnzc        6.816548    0.296092  ...    0.004390       12.511097
#
#               SPM_tau_fall_r   SPM_chi_r  MHPS_ratio_r  MHPS_low_r  \
# ZTF17aadlxmv       28.738520    1.205094        -999.0   -0.000134
# ZTF18aaaqexr       32.402479 -999.000000        -999.0 -999.000000
# ZTF18aacdbzx       24.026549 -999.000000        -999.0   -0.000061
# ZTF18aadmssd       45.864717    1.883757        -999.0   -0.000276
# ZTF18aadzfso       84.149827    0.020970        -999.0   -0.000085
# ...                      ...         ...           ...         ...
# ZTF20abgbiet       20.394612    0.616494        -999.0   -0.000074
# ZTF20abgbxfm       28.450412    0.048687        -999.0   -0.000035
# ZTF20abgdtmv       15.758271    0.055752        -999.0   -0.000031
# ZTF20abgfekk       30.064705    0.072832        -999.0   -0.000160
# ZTF20abhvnzc        6.616611    1.250485        -999.0   -0.000167
#
#                MHPS_high_r  MHPS_non_zero_r  MHPS_PN_flag_r  __y__
# ZTF17aadlxmv  2.697572e-16             16.0             1.0      1
# ZTF18aaaqexr -9.990000e+02              0.0             1.0      1
# ZTF18aacdbzx  4.453327e-16              6.0             1.0      2
# ZTF18aadmssd  1.348151e-16             12.0             1.0      3
# ZTF18aadzfso  1.155403e-15             13.0             1.0      1
# ...                    ...              ...             ...    ...
# ZTF20abgbiet  2.984120e-16              6.0             1.0      1
# ZTF20abgbxfm  1.247395e-16             36.0             1.0      1
# ZTF20abgdtmv  1.967177e-16             18.0             1.0      1
# ZTF20abgfekk  4.409386e-16             20.0             1.0      1
# ZTF20abhvnzc  1.564981e-15             10.0             1.0      1
#
# [1163 rows x 31 columns]
